# %%
import pandas as pd

# %%
df = pd.read_csv('results.csv')

# %%
df.columns
# Out:
# Index(['                  epoch', '             train/loss',
#        '              test/loss', '  metrics/accuracy_top1',
#        '  metrics/accuracy_top5', '                   lr/0'],
#       dtype='object')

# %%
df.plot.line(x = '                  epoch')
# Out:
# <AxesSubplot:xlabel='                  epoch'>

# %%
# importing package
import matplotlib.pyplot as plt
import numpy as np
  
# create data
x = df['                  epoch']
y = df['  metrics/accuracy_top1']
g = df['              test/loss']
# plot lines
plt.figure(figsize=(12,12))
plt.plot(x, y, 'r', label = "Test Accuracy")
plt.plot(x, z, 'b',label = "Test loss")
plt.legend()

plt.show()

# %%
z
# Out:
# 0     0.58915
# 1     0.64341
# 2     0.65116
# 3     0.58140
# 4     0.55814
# 5     0.41860
# 6     0.79845
# 7     0.85271
# 8     0.75194
# 9     0.82946
# 10    0.74419
# 11    0.83721
# 12    0.53488
# 13    0.89147
# 14    0.89922
# 15    0.90698
# 16    0.89922
# 17    0.90698
# 18    0.87597
# 19    0.91473
# 20    0.92248
# 21    0.90698
# 22    0.89922
# 23    0.91473
# 24    0.90698
# 25    0.91473
# 26    0.81395
# 27    0.89147
# 28    0.92248
# 29    0.91473
# 30    0.89147
# 31    0.92248
# 32    0.89147
# 33    0.90698
# 34    0.93023
# 35    0.93798
# 36    0.91473
# 37    0.92248
# 38    0.93023
# 39    0.92248
# 40    0.91473
# 41    0.90698
# 42    0.90698
# 43    0.92248
# 44    0.90698
# 45    0.90698
# 46    0.91473
# 47    0.90698
# 48    0.92248
# 49    0.89922
# Name:   metrics/accuracy_top1, dtype: float64
