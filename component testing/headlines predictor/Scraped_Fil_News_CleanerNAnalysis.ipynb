# %%
import pandas as pd
import nltk
import numpy as np
#doesnt lemmatize properly
#cannot do the same features as english due to tagalog being a low resource language

# %%
def remove_quotes(x):
    x = x.replace('“', '')
    x = x.replace('”', '')
    x = x.replace('"', '')
    return x

# %%
df = pd.read_csv('Scraped_Tagalog_Headlines.csv')
df = df.dropna(axis=0).reset_index(drop=True)
df['Statement'] = df['Statement'].apply(lambda x: remove_quotes(x))
df
# Out:
#                                               Statement Rating
# 0           Lalaki patay sa pamamaril sa Tondo, Maynila   Real
# 1     50 Pinoy na naipit sa kaguluhan sa Sudan, nail...   Real
# 2     #BoyingResign: Netizens galit kay DOJ Chief Re...   Real
# 3     ‘Backdoor entry’ ng Grab sa motorcycle taxi pi...   Real
# 4       Doktor nangangamba na na-mild stroke si De Lima   Real
# ...                                                 ...    ...
# 3447  Remembering Marky Cielo, Proud Igorot and Star...   Fake
# 3448  Netizen, inilabas ang sekretong galit dahil la...   Fake
# 3449  Pinoy Vlogger na tumulong kay Nas Daily noon, ...   Fake
# 3450  GRABE! UNANG GABI NG LAMAY SA BUROL NI KRIS AQ...   Fake
# 3451   Isang tattoo artist may walong asawa at magka...   Fake
#
# [3452 rows x 2 columns]

# %%
import spacy
import spacy.lang.tl as s_tl
tl_stopwords = s_tl.stop_words.STOP_WORDS

# %%
from sacremoses import MosesTokenizer
import simplemma as slma
mt = MosesTokenizer('tl')

# %%
# from bs4 import BeautifulSoup
# from requests_html import HTMLSession
# from collections import defaultdict
# session = HTMLSession()


# def slang_scraper(url, element, n_pages, site_abbv ,test=False):
#     exceptions = ['Posts navigation',"Search the Dictionary","LET’S STUDY THE BASICS","POPULAR TOPICS","ENTRIES JUST UPDATED","Search our Website", 'Filipino Slang – Inverted Syllables', 'Examples of Filipino Slang Words']
#     headlines = []
    
#     for n in range(1, n_pages):
#         if n_pages > 2:
#             r = session.get(url.format(page=n))
#         else:
#             r = session.get(url)
#         soup = BeautifulSoup(r.content, "html.parser")
#         articles = soup.find_all(element)
#         for headline in articles:
#             acc_text = headline.text
#             if acc_text != '' and acc_text not in exceptions:
#                 headlines.append(acc_text.lower())
#                 print(acc_text.lower())

#         if test == True:
#             break
    
#     if test == True:
#         return headlines
    
#     print(len(headlines))
#     file = open(f'{site_abbv}_words.txt','w')
#     for news in headlines:
#         file.write(news+"\n")
#     file.close()
#     return headlines

# %%
with open('tag_slang_words.txt') as f:
    lines = f.readlines()
    slang_words = [line.replace('\n','') for line in lines]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-416b94995ab0> in <module>
# ----> 1 with open('tag_slang_words.txt') as f:
#       2     lines = f.readlines()
#       3     slang_words = [line.replace('\n','') for line in lines]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tag_slang_words.txt'

# %%
slang_words
# Out:
# ['bagets',
#  'dehins',
#  'astig',
#  'utol',
#  'tsekot',
#  'erpat',
#  'resbak',
#  'bokal',
#  'monay',
#  'topak',
#  'hokage',
#  'damo',
#  'pasharks',
#  'pashark',
#  'badap',
#  'abnoy',
#  'endo',
#  'oblo',
#  'matsala',
#  'ermat',
#  'ebak',
#  'hinayupak',
#  'pakshet',
#  'helmet',
#  'lespu',
#  'amp',
#  'adik',
#  'hugot',
#  'kepyas',
#  'budol',
#  'anyare',
#  'ansabe',
#  'pak',
#  'tol',
#  'chaka',
#  'jowa',
#  'paminta',
#  'apir',
#  'wais',
#  'petmalu',
#  'tisoy',
#  'epal',
#  'banat',
#  'hanash',
#  'sinetch',
#  'jeproks',
#  'scoobs',
#  'plok-plok',
#  'burger',
#  'isputing',
#  'buking',
#  'atabs',
#  'jakol',
#  'getsing',
#  'pototoy',
#  'bomalabs',
#  'shunga',
#  'adidas',
#  'stariray',
#  'repakol',
#  'omsim',
#  'praning',
#  'asumera',
#  'erp',
#  'gora',
#  'istokwa',
#  'gapak',
#  'momol',
#  'oum',
#  'werpa',
#  'sholbog',
#  'atik',
#  'petiks',
#  'purita',
#  'yosi',
#  'bopol',
#  'etats',
#  'harbat',
#  'engot',
#  'senglot',
#  'tsibugan',
#  'chuway',
#  'tsibog',
#  'moot',
#  'kaburyo',
#  'lomag',
#  'amats',
#  'etneb',
#  'junakis',
#  'adnagam',
#  'taklesa',
#  'dedbol',
#  'basted',
#  'gamol',
#  'chipipay',
#  'juts',
#  'songs',
#  'dyologs',
#  'jowable',
#  'noypi',
#  'enka',
#  'tsedeng',
#  'imba',
#  'pabebe',
#  'tipar',
#  'lakompake',
#  'tepok',
#  'brad',
#  'enebe',
#  'charing',
#  'goli',
#  'golets',
#  'lonta',
#  'carps',
#  'tate',
#  'lobat',
#  'waley',
#  'okray',
#  'peg',
#  'lodi',
#  'ayjusko',
#  'alaws',
#  'rapsa',
#  'dyahe',
#  'tsikot',
#  'sanpit',
#  'swak',
#  'ampogi',
#  'chos',
#  'nenok',
#  'timbs',
#  'promdi',
#  'daks',
#  'walastik',
#  'rema',
#  'sags',
#  'starbs',
#  'pots',
#  'gumps',
#  'pics',
#  'etsusera',
#  'olats',
#  'tsiken',
#  'naano',
#  'ksp',
#  'syota',
#  'momshie',
#  'bes',
#  'kebs',
#  'jolog',
#  'nakakagv',
#  'iskapo',
#  'keribels',
#  'lafang',
#  'langya',
#  'lokbu',
#  'ganern',
#  'tomoh']

# %%
# curse_words = slang_scraper('https://www.buzzfeed.com/isabellelaureta/anak-bad-yan', 
#                              ('h2', {'class':'subbuzz__header subbuzz__header--standard subbuzz__title '}), 
#                             2, 
#                              'curse', 
#                              test=False)

# %%
# https://www.buzzfeed.com/isabellelaureta/anak-bad-yan
with open('curse_words.txt') as f:
    lines = f.readlines()
    curse_words = [line.replace('\n','') for line in lines]

# %%
curse_words
# Out:
# ['hudas',
#  'putangina',
#  'lintik',
#  'ulol',
#  'gago',
#  'tarantado',
#  'buwisit',
#  'burat',
#  'kupal',
#  'leche',
#  'ungas',
#  'punyeta',
#  'hinayupak',
#  'pucha',
#  'pestengyawa',
#  'pakshet',
#  'tanga',
#  'tae',
#  'panget',
#  'titi',
#  'puta',
#  'kantotero',
#  'bobo',
#  'panget']

# %%
import re
import string
from collections import Counter

def remove_tl_stopwords(x):
    no_sw = [word for word in x if word not in tl_stopwords]
    return no_sw

def clean_data_untokenized(x):
    x = re.sub("[^a-zA-Z0-9']+", " ", x)
    tokens = x.lower().split()
    # x = mt.tokenize(x)
    #tokens = [token.lower() for token in x ]
    # tokens = x.lower().split() #removes non alphabet, undercase, then splits
    no_sw = remove_tl_stopwords(tokens)
    #lemmatized_tokens = [slma.lemmatize(token, lang='tl') for token in no_sw]
    cleaned = ' '.join(no_sw)
    return cleaned

def clean_tokenized(x):
    x = mt.tokenize(x)
    tokens = [token.lower() for token in x ]
    #tokens = x.lower().split() #removes non alphabet, undercase, then splits
    no_sw = remove_tl_stopwords(tokens)
    #lemmatized_tokens = [slma.lemmatize(token, lang='tl') for token in no_sw]
    return no_sw


def count_unique(x):
    x = re.sub("[^a-zA-Z0-9']+", " ", x)
    tokens = x.lower().split() #removes non alphabet, undercase, then splits
    counts = Counter(tokens)
    unique = sum(value == 1 for value in counts.values())
    return unique

def punc_percenatage(x):
    punctuation = string.punctuation
    return len([c for c in x if c in punctuation])/len(mt.tokenize(x))



    
    #lol please re run the eng news cleaner when this is done

def i_punc_perc(x):
    punctuation_dict = {'.':'period', ',':'comma', ':':'colon', 
                    ';':'semicolon', '?':'question mark', 
                    '!':'exclamation mark', '-':'dash', "'": 'apostrophe',
                    '(':'open parenthesis', ')':'close parenthesis'}

    puncs = [punctuation_dict[punc] for punc in x['Statement'] if punc in punctuation_dict.keys()]

    punc_count_dic = {}
    for punc in list(punctuation_dict.values()):
        punc_count_dic[punc] = puncs.count(punc)/len(mt.tokenize(x['Statement']))

    #period, comma, colon, semicolon, question mark, exclamation mark, dash, apostrophe, open parenthesis, close parenthesis
    return tuple(punc_count_dic.values())


def cap_words(x):
    x = mt.tokenize(x)
    return sum(word.isupper() for word in x)/len(x)

#scraped slangwords from https://www.tagaloglang.com/tag/filipino-slang/
def tagalog_slang(x):
    x = re.sub("[^a-zA-Z0-9']+", " ", x)
    tokens = x.lower().split() #removes non alphabet, undercase, then splits
    return len([word for word in tokens if  word in slang_words])/len(x)

def tagalog_curse(x):
    x = re.sub("[^a-zA-Z0-9']+", " ", x)
    tokens = x.lower().split() #removes non alphabet, undercase, then splits
    return len([word for word in tokens if  word in curse_words])/len(x)


def pos_num(x):
    tags = nltk.pos_tag(mt.tokenize(x))
    count = sum(value[1] == 'CD' for value in tags)
    return count/len(tags)

# %%
df['cleaned'] = df['Statement'].apply(lambda x: clean_data_untokenized(x))
df['cleaned tokenized'] = df['Statement'].apply(lambda x: clean_tokenized(x))
df[['period%', 'comma%', 'colon%', 
    'semicolon%', 'question mark%', 
    'exclamation mark%', 'dash%', 'apostrophe%', 
    'open parenthesis%', 'close parenthesis%']] = df.apply(i_punc_perc, axis=1, result_type="expand")

# %%
df['capitalized%'] = df['Statement'].apply(lambda x: cap_words(x))
df['slang words%'] = df['Statement'].apply(lambda x: tagalog_slang(x))
df['curse words%'] = df['Statement'].apply(lambda x: tagalog_curse(x))
df['with numericals%'] = df['Statement'].apply(lambda x:pos_num(x))

# %%
def generate_N_grams(text,ngram=1):
  text = re.sub("[^a-zA-Z0-9']+", " ", text)
  words=[word.strip().lower() for word in text.split(" ") if word not in tl_stopwords]  
  print("Sentence after removing stopwords:",words)
  temp=zip(*[words[i:] for i in range(0,ngram)])
  ans=[' '.join(ngram) for ngram in temp]
  return ans


df['bigrams'] = df['cleaned'].apply(lambda x: generate_N_grams(x,2))
# Out:
# Sentence after removing stopwords: ['lalaki', 'patay', 'pamamaril', 'tondo', 'maynila']
# Sentence after removing stopwords: ['50', 'pinoy', 'naipit', 'kaguluhan', 'sudan', 'nailikas']
# Sentence after removing stopwords: ['boyingresign', 'netizens', 'galit', 'kay', 'doj', 'chief', 'remulla', 'matapos', 'mahulihan', 'high', 'grade', 'marijuana', 'anak']
# Sentence after removing stopwords: ['backdoor', 'entry', 'grab', 'motorcycle', 'taxi', 'pilot', 'pinaiimbestigahan']
# Sentence after removing stopwords: ['doktor', 'nangangamba', 'mild', 'stroke', 'de']
# Sentence after removing stopwords: ['japan', 'coast', 'guard', 'nagpasalamat', 'pcg', 'pagsagip', 'japanese', 'crew', 'nakaranas', 'maritime', 'accident']
# Sentence after removing stopwords: ['employment', 'rate', 'umangat', 'noong', 'pebrero']
# Sentence after removing stopwords: ["'amang'", 'landfall', 'lagonoy', 'camarines', 'sur', '11', 'lugar', 'nasa', 'signal', 'no', '1']
# Sentence after removing stopwords: ['robinhood', 'padilla', 'gawing', 'legal', 'paggamit', 'medical', 'marijuana']
# Sentence after removing stopwords: ['pangulong', 'duterte', 'sinisisi', 'kakulangan', 'covid', '19', 'vaccines']
# Sentence after removing stopwords: ['isabela', 'lgu', 'posibleng', 'natagpuan', 'bahagi', 'nawawalang', 'cessna', 'plane']
# Sentence after removing stopwords: ['9', 'tips', 'makatipid', 'tubig', 'tag', 'init']
# Sentence after removing stopwords: ['bagyong', 'obet', 'posible', 'pang', 'lumakas', 'signal', 'no', '1', 'nakataas', 'bahagi', 'northern', 'luzon']
# Sentence after removing stopwords: ['download', 'speed', 'fixed', 'broadband', 'internet', 'bansa', 'muling', 'tumaas']
# Sentence after removing stopwords: ['580', 'preso', 'sabay', 'sabay', 'pinalaya', "'good", "behavior'"]
# Sentence after removing stopwords: ['bitay', 'sangkot', 'ilegal', 'droga', 'itutulak', 'rep', 'barbers']
# Sentence after removing stopwords: ['pagiging', 'no', '3', 'robin', 'padilla', 'survey', 'ipinagtanggol', 'ipatupad', 'partylist', 'natin', 'siyang', 'husgahan']
# Sentence after removing stopwords: ['jeepney', 'group', 'nanawagan', 'ltfrb', 'palawigin', 'deadline', 'implementasyon', 'jeepney', 'modernization', 'program']
# Sentence after removing stopwords: ['lanao', 'del', 'sur', 'gov', 'adiong', 'sugatan', 'ambush', '4', 'kasamahan', 'patay']
# Sentence after removing stopwords: ['pasahe', 'lrt', 'nagbabadyang', 'tumaas', 'matapos', 'aprubahan', 'ltfrb']
# Sentence after removing stopwords: ['dict', 'deadline', 'sim', 'registration', 'abril', '26', 'rin']
# Sentence after removing stopwords: ['anak', 'nina', 'luis', 'manzano', 'jessy', 'mendiola', 'baby', 'peanut', 'bininyagan', 'alex', 'gonzaga', 'nikki', 'gil', 'tumayong', 'ninang']
# Sentence after removing stopwords: ['pnp', 'magde', 'deploy', 'mas', 'maraming', 'pulis', 'ngayong', 'kapaskuhan']
# Sentence after removing stopwords: ['teves', 'humingi', 'tulong', 'kay', 'pbbm', 'umano', 'y', 'panggigipit', 'ilang', 'opisyal']
# Sentence after removing stopwords: ['dswd', 'up', 'tutulong', 'habulin', 'child', 'support', 'magulang', 'ibang', 'bansa']
# Sentence after removing stopwords: ['ilang', 'lugar', 'visayas', 'mindanao', 'positibo', 'red', 'tide', 'bfar']
# Sentence after removing stopwords: ['anak', 'doj', 'chief', 'remulla', 'not', 'guilty', 'kasong', 'illegal', 'drug', 'possession']
# Sentence after removing stopwords: ['ngo', 'nababahala', 'pagkalat', 'covid', '19', 'inililikas', 'aalburutong', 'bulkang', 'taal']
# Sentence after removing stopwords: ['dating', 'japanese', 'pm', 'shinzo', 'abe', 'pumanaw', 'matapos', 'barilin']
# Sentence after removing stopwords: ['romualdez', 'dismayado', 'pagkadawit', 'ilang', 'pnp', 'officials', 'p6', '7', 'billion', 'shabu']
# Sentence after removing stopwords: ['higit', '300', 'manlalaro', 'lumahok', 'finals', 'rodeo', 'masbate']
# Sentence after removing stopwords: ['bong', 'go', 'china', 'taiwan', 'tension', 'ofws', 'tiyaking', 'ligtas']
# Sentence after removing stopwords: ['giant', 'billboard', 'imelda', 'marcos', 'trending', 'social', 'media']
# Sentence after removing stopwords: ['grupo', 'nanawagan', 'deped', 'chedna', 'tugunan', 'tinwag', 'vape', 'epidemic', 'kabataang', 'pilipino']
# Sentence after removing stopwords: ['support', 'group', 'mapalaya', 'pinakamatandang', 'bilanggong', 'pulitikal']
# Sentence after removing stopwords: ['oriental', 'mindoro', 'makaranas', 'blackout']
# Sentence after removing stopwords: ['pilipinong', 'kabilang', 'namatay', 'banggaan', '2', 'tren', 'greece']
# Sentence after removing stopwords: ['kampo', 'cong', 'teves', 'ki', 'nuwestyong', 'narekober', 'granada', 'kaniyang', 'tahanan']
# Sentence after removing stopwords: ['new', 'year', 'message', 'pbbm', 'filipino', 'chinese', 'have', 'deeper', 'compassion', 'to', 'those', 'who', 'have', 'less', 'in', 'life']
# Sentence after removing stopwords: ['p4', '7', 'b', 'halaga', 'service', 'contracting', 'payouts', 'naibigay', 'driver', 'operator']
# Sentence after removing stopwords: ['opisyal', 'barangay', 'san', 'jose', 'del', 'monte', 'sorry', 'grab', 'rider', 'kaugnay', 'kontrobersiya', 'lugaw']
# Sentence after removing stopwords: ['mambabatas', 'naghain', 'resolusyon', 'upang', 'imbestigahan', 'kuwestyonableng', 'third', 'party', 'auditor', 'pagcor']
# Sentence after removing stopwords: ['globe', 'planthappinessph', 'mental', 'health', 'campaign', 'umani', 'higit', '168', '7', 'milyong', 'views', 'tiktok']
# Sentence after removing stopwords: ['kakulangan', 'imprastraktura', 'resources', 'nakikitang', 'most', 'pressing', 'issue', 'kinakaharap', 'sektor', 'edukasyon', 'bansa']
# Sentence after removing stopwords: ['qc', 'traffic', 'enforcer', 'nakapagsagip', 'siklista', 'masagasaan', 'mamatay']
# Sentence after removing stopwords: ['panukala', 'magbabawal', 'substitution', 'of', 'candidacy', 'inihain', 'kamara']
# Sentence after removing stopwords: ['pangulong', 'marcos', 'pabahay', 'kada', 'taon', 'lalampas', '1', 'milyon']
# Sentence after removing stopwords: ['pagsusuot', 'face', 'shield', 'kinakailangan', 'maynila', 'maliban', 'medical', 'facilities']
# Sentence after removing stopwords: ['popcom', 'naaalarma', 'teen', 'pregnancy', 'pinakabata', 'nasa', 'edad', '10']
# Sentence after removing stopwords: ['2', 'batang', 'magkapatid', 'patay', 'sunog', 'mandaluyong']
# Sentence after removing stopwords: ['signal', 'no', '1', 'nakataas', 'rin', 'bahagi', 'luzon', 'classes', 'suspension', 'idineklara', 'ilang', 'probinsya']
# Sentence after removing stopwords: ['balikatan', 'exercises', '2023', 'all', 'set']
# Sentence after removing stopwords: ['ppa', 'libreng', 'pagkain', 'mai', 'stranded', 'pasahero', 'pantalan']
# Sentence after removing stopwords: ['partial', 'solar', 'eclipse', 'nasilayan', 'ibang', 'lugar', 'ph']
# Sentence after removing stopwords: ['rider', 'nangholdap', 'cake', 'shop', 'quezon', 'city']
# Sentence after removing stopwords: ['manny', 'villar', 'nangunguna', 'richest', 'filipinos', 'forbes', 'magazine']
# Sentence after removing stopwords: ['dumalo', 'uniteam', 'rally', 'nawalan', 'cellphone', 'wallet', 'parang', 'awa', 'n', 'yo', 'po', 'pakisauli', 'lang', 'po']
# Sentence after removing stopwords: ['mahihirap', 'bacolod', 'city', 'tinulungan', 'bong', 'go']
# Sentence after removing stopwords: ['apela', 'newsnet', 'ibinasura', 'palasyo']
# Sentence after removing stopwords: ['pnp', 'cidg', 'binasura', 'pagkakasangkot', 'police', 'escorts', 'gov', 'degamo', 'pagpatay']
# Sentence after removing stopwords: ['mmda', 'number', 'coding', 'scheme', 'suspendido', 'april', '6', '10']
# Sentence after removing stopwords: ['p128', 'milyong', 'pondo', 'nakalaan', 'biktima', 'tropical', 'storm', 'maring']
# Sentence after removing stopwords: ['panukalang', 'naglalayong', 'suspendihin', 'mother', 'tongue', 'medium', 'pagtuturo', 'bata', 'lusot', 'ikalawang', 'pagbasa', 'kamara']
# Sentence after removing stopwords: ['mahigit', 'p6', '8m', 'halaga', "'shabu'", 'nasabat', 'buy', 'bust', 'operation', 'taguig']
# Sentence after removing stopwords: ['takot', 'filipino', 'covid', '19', 'record', 'high', 'sws', 'survey']
# Sentence after removing stopwords: ['dotr', 'maghihigpit', 'seguridad', 'mrt', '3', 'matapos', 'tumalon', 'pasahero']
# Sentence after removing stopwords: ['barbie', 'forteza', 'pinapili', 'love', 'career', 'netizens', 'bumilib', 'sagot']
# Sentence after removing stopwords: ['hirit', 'transport', 'group', 'p3', 'dagdag', 'pasahe', 'pinalagan']
# Sentence after removing stopwords: ['oldest', 'pinoy', 'lola', 'francisca', 'susano', 'pumanaw', 'edad', '124']
# Sentence after removing stopwords: ['gobyerno', 'wala', 'gagawing', 'aksyon', 'matapos', 'ibasura', 'icc', 'apela', 'bansa', 'suspendihin', 'imbestigasyon', 'drug', 'war']
# Sentence after removing stopwords: ['ika', 'mananaya', 'nanalo', 'jackpot', 'lotto', 'loob', 'linggo']
# Sentence after removing stopwords: ['kaso', 'covid', '19', 'pilipinas', 'sumampa', 'higit', '784', '000']
# Sentence after removing stopwords: ['kampo', 'pinaslang', 'ex', 'mayor', 'ateneo', 'campus', 'umalma', 'isyu', 'ilegal', 'droga', 'that', 'is', 'not', 'true']
# Sentence after removing stopwords: ['fda', '18', 'bata', 'nakaranas', 'side', 'effect', 'sangobion', 'kids', 'syrup']
# Sentence after removing stopwords: ['mexican', 'beauty', 'queen', 'kaniyang', 'partner', 'kulong', 'pagsikwat', 'alak', 'spain']
# Sentence after removing stopwords: ['sotto', 'hinikayat', 'gobyerno', 'magpatupad', 'price', 'freeze', 'lugar', 'apektado', 'bagyong', 'odette']
# Sentence after removing stopwords: ['bwelta', 'bongbong', 'bashers', 'duwag', 'tao', 'wala', 'akong', 'iniiwasan']
# Sentence after removing stopwords: ['dahilan', 'paglihis', 'tren', "'di", 'tukoy', 'pnr']
# Sentence after removing stopwords: ['asawa', '3', 'anak', 'patay', 'sunog', 'natagpuan', 'rumespondeng', 'fire', 'marshall', 'magkakayakap']
# Sentence after removing stopwords: ['infinite', 'radio', 'calbayog', 'nagdiwang', 'ikalawang', 'anibersaryo']
# Sentence after removing stopwords: ['senador', 'paimbestigahan', 'operasyon', 'pcso', 'katanungan', 'lehitimong', 'nananalo', 'lotto', 'grand', 'prize']
# Sentence after removing stopwords: ['provisional', 'toll', 'rates', 'skyway', 'stage', '3', 'aprubado']
# Sentence after removing stopwords: ['lalaki', 'huli', 'pangmomolestiya', 'menor', 'de', 'edad', 'qc']
# Sentence after removing stopwords: ['13', '000', 'mt', 'imported', 'galunggong', 'dumating', 'bansa']
# Sentence after removing stopwords: ['pba', 'mapait', 'game', '4', 'loss', 'kay', 'standhardinger']
# Sentence after removing stopwords: ['doe', 'tiniyak', 'red', 'yellow', 'alert', 'malampaya', 'maintenance']
# Sentence after removing stopwords: ['panel', 'review', 'result', 'pnp', 'officials', 're', 'illegal', 'drug', 'trade', 'matatapos', 'loob', '2', 'linggo']
# Sentence after removing stopwords: ['suspensiyon', 'trump', 'facebook', 'tatagal', '2023']
# Sentence after removing stopwords: ['posts', 'navigation']
# Sentence after removing stopwords: ['pagpapatuloy', 'allowance', 'healthworkers', 'ipinag', 'utos', 'pangulo']
# Sentence after removing stopwords: ['teves', 'dadalo', 'senate', 'probe', 'degamo', 'slay']
# Sentence after removing stopwords: ['pcso', 'umaasa', 'malaking', 'kita', 'sweepstakes', 'malnutrisyon', 'lalabanan']
# Sentence after removing stopwords: ['biyahe', 'pnr', 'maynila', 'naantala', 'kotseng', 'bumalandra', 'riles']
# Sentence after removing stopwords: ['senador', 'humiling', 'congressional', 'inquiry', 'status', 'pagpapatupad', 'anti', 'bullying', 'act']
# Sentence after removing stopwords: ['look', 'lugar', 'nakasailalim', 'lockdown', 'qc']
# Sentence after removing stopwords: ['karagdagang', 'alokasyon', 'tubig', 'mwss', 'kakayanin', 'nwrb']
# Sentence after removing stopwords: ['p1', '6b', 'inilaan', 'rehabilitasyon', 'manila', 'bay']
# Sentence after removing stopwords: ['vico', 'sotto', 'apektado', 'cyberlibel', 'case', 'isinampa', 'bernardo', 'it', 's', 'nothing', 'personal']
# Sentence after removing stopwords: ['knows', 'n', 'yo', 'ba', 'maiiwasan', 'heatstroke', 'lalo', 'ngayong', 'tag', 'init']
# Sentence after removing stopwords: ['juan', 'ponce', 'enrile', 'tinamaan', 'covid', '19', 'i', 'm', 'not', 'gonna', 'die', 'yet']
# Sentence after removing stopwords: ['mundo', 'teves', 'paliliitin', 'ituturing', 'terorista', 'doj']
# Sentence after removing stopwords: ['lto', 'pinaigting', 'kampanya', 'overloading', 'vehicles']
# Sentence after removing stopwords: ['101', 'itinaas', 'kaso', 'typhoid', 'doh']
# Sentence after removing stopwords: ['kilalanin', 'top', '30', 'bar', 'passers', 'taong', '2022']
# Sentence after removing stopwords: ['marcos', 'bumuo', 'inter', 'agency', 'committtee', 'tututok', 'inflation']
# Sentence after removing stopwords: ['teves', 'kinatatakutan', 'umanong', 'pamilya', 'negros', 'oriental']
# Sentence after removing stopwords: ['paggamit', 'face', 'shield', 'pinag', 'aaralang', 'ibalik', 'harap', 'banta', 'omicron']
# Sentence after removing stopwords: ['ilang', 'lugar', 'maynila', 'magpapatupad', 'liquor', 'ban']
# Sentence after removing stopwords: ['presyo', 'petrolyo', "'dagdag", "bawas'", 'abril', '18']
# Sentence after removing stopwords: ['nanay', 'pasig', 'pinatay', 'kaniya', 'umanong', 'sariling', 'anak']
# Sentence after removing stopwords: ['3', 'patay', 'salpukan', 'motor', 'kotse', 'batangas']
# Sentence after removing stopwords: ['remulla', 'mensahe', 'kay', 'teves', 'jr', 'ngayong', 'semana', 'santa']
# Sentence after removing stopwords: ['kongreso', 'tinaasan', 'cancer', 'funds', 'pilipino', 'p1', '56b']
# Sentence after removing stopwords: ['2', 'lalaki', 'huli', 'ilegal', 'umanong', 'pagbebenta', 'e', 'cigarettes', 'vape', 'products']
# Sentence after removing stopwords: ['20', 'probinsiya', 'lang', 'di', 'napapasok', 'asf']
# Sentence after removing stopwords: ['brigada', 'news', 'philippines']
# Sentence after removing stopwords: ['bulkang', 'mayon', 'nagtala', 'pagyanig', 'nakataas', 'rin', 'alert', 'level', '2']
# Sentence after removing stopwords: ['bong', 'go', 'linggo', 'pagkabuhay', 'wag', 'mawalan', 'asa', 'tiwala']
# Sentence after removing stopwords: ['hugis', 'pusong', 'clearing', 'woodland', 'farmer', 'namayapang', 'asawa']
# Sentence after removing stopwords: ['covid', '19', 'aakyat', '600', 'kada', 'araw', 'mayo', 'doh']
# Sentence after removing stopwords: ['pagsugpo', 'pang', 'aabuso', 'paaralan', 'pinaigting', 'deped', 'naglunsad', 'helpline']
# Sentence after removing stopwords: ['dayuhang', 'nagmamaltrato', 'asawang', 'pinay', 'cebu', 'arestado']
# Sentence after removing stopwords: ['marcos', 'inaasahang', 'magsasagawa', 'state', 'visit', 'france']
# Sentence after removing stopwords: ['teves', 'camp', 'umaasang', 'magiging', 'witch', 'hunt', 'senate', 'hearing', 'degamo', 'slay', 'case']
# Sentence after removing stopwords: ['mrt', '3', 'libreng', 'sakay', 'beterano', 'april', '10', 'to', '12']
# Sentence after removing stopwords: ['senador', 'nanawagan', 'philhealth', 'bigyan', 'kaunting', 'kaluwagan', 'ofws', 'pagbabayad', 'premium', 'contributions']
# Sentence after removing stopwords: ['vp', 'leni', 'robredo', 'kakandidatong', 'pangulo', 'bansa', 'buong', 'buo', 'loob']
# Sentence after removing stopwords: ['marcos', 'kailangang', 'import', 'produkto', 'sakaling', 'malakas', 'msmes']
# Sentence after removing stopwords: ['vg', 'jolo', 'revilla', 'prayoridad', 'sahod', 'manggagawang', 'cavite']
# Sentence after removing stopwords: ['ex', 'dfa', 'sec', 'albert', 'del', 'rosario', 'pumanaw']
# Sentence after removing stopwords: ['ayuda', 'dswd', 'suspendido', 'muna', 'ngayong', 'holy', 'week']
# Sentence after removing stopwords: ['grab', 'nangako', 'kay', 'pangulong', 'marcos', 'kalahating', 'milyong', 'trabaho', 'pilipino']
# Sentence after removing stopwords: ['lutong', 'pinoy', 'gustong', 'ipakilala', 'loren', 'legarda', 'buong', 'mundo']
# Sentence after removing stopwords: ['bi', 'inaasahang', 'papalo', '50k', 'arrivals', 'holy', 'week']
# Sentence after removing stopwords: ['barker', 'quezon', 'city', 'binaril', 'taxi', 'driver', 'daw', 'p5']
# Sentence after removing stopwords: ['remote', 'work', 'facebook', 'forever']
# Sentence after removing stopwords: ['doh', 'nakapagtala', 'halos', '1', '500', 'kaso', 'hiv', 'noong', 'enero']
# Sentence after removing stopwords: ['ina', 'dr', 'chao', 'tiao', 'yumol', 'nanawagan', 'kay', 'bongbong', 'marcos', 'nasa', 'panganib']
# Sentence after removing stopwords: ['5', '3', 'lindol', 'yumanig', 'ilang', 'bahagi', 'luzon']
# Sentence after removing stopwords: ['dating', 'pulis', 'sangkot', 'pagpatay', '2', 'teenager', 'hinatulan', 'korte', '40', 'taong', 'pagkakakulong']
# Sentence after removing stopwords: ['obispo', 'batanes', 'humihingi', 'tulong', 'nabiktima', 'bagyong', 'kiko']
# Sentence after removing stopwords: ['sky', 'lantern', 'thailand', 'bumagsak', 'sumabog']
# Sentence after removing stopwords: ['higit', '100', 'property', 'developers', 't', 'uuml', 'rkiye', 'inaresto', 'kaugnay', 'pagguho', 'gusali', 'lindol']
# Sentence after removing stopwords: ['globe', 'libreng', 'tawag', 'charging', 'wifi', 'nakahanda', 'apektado', 'dante']
# Sentence after removing stopwords: ["umano'y", 'illegal', 'recruiter', 'nangako', 'trabaho', 'canada', 'timbog']
# Sentence after removing stopwords: ['vp', 'leni', 'natuwa', 'pagbisita', 'tarlac', 'pnoy', 'be', 'gone', 'now', 'but', 'josh', 'being', 'there', 'really', 'meant', 'a', 'lot']
# Sentence after removing stopwords: ['food', 'and', 'waterborne', 'disease', 'bansa', 'tumaas']
# Sentence after removing stopwords: ['7', 'araw', 'sim', 'registration', 'deadline', 'pagpaparehistro', 'rin', 'extended']
# Sentence after removing stopwords: ['veteran', 'broadcaster', 'dong', 'puno', 'pumanaw', 'edad', '76']
# Sentence after removing stopwords: ['ex', 'gov', 'teves', 'naghain', 'waiver', 'doj', 'nagpapahintulot', 'tingnan', 'phone', 'bank', 'accounts']
# Sentence after removing stopwords: ['pang', 'lugar', 'muntinlupa', 'naka', 'lockdown', 'rin']
# Sentence after removing stopwords: ['self', 'confessed', 'gunman', 'percy', 'lapid', 'slay', 'case', 'joel', 'escoria', 'nailipat', 'pnp', 'custodial', 'center']
# Sentence after removing stopwords: ['senador', 'zubiri', 'raw', 'maintindihan', 'madaliin', 'kamara', 'cha', 'cha']
# Sentence after removing stopwords: ['who', 'nababahala', 'secondary', 'health', 'crisis', 'turkey', 'kasunod', 'magnitude', '7', '8', 'lindol']
# Sentence after removing stopwords: ['asia', 's', 'superstar', 'kathryn', 'bernardo', 'tnt', 'tropa']
# Sentence after removing stopwords: ['dating', 'desk', 'officer', 'pnp', 'bayawan', 'negros', 'oriental', 'pina', 'cite', 'in', 'contempt', 'senado']
# Sentence after removing stopwords: ['pnp', 'blanko', 'kinaroroonan', 'drug', 'lord', 'peter', 'lim']
# Sentence after removing stopwords: ['pinabulaanang', 'tinurture', 'muna', 'asawang', 'tiamzon', 'patayin']
# Sentence after removing stopwords: ['bi', 'iniimbestigahan', 'iniulat', 'illegal', 'scamming', 'hubs']
# Sentence after removing stopwords: ['pagbabayad', 'buwis', 'caloocan', 'city', 'online', 'rin']
# Sentence after removing stopwords: ['ex', 'dfa', 'chief', 'albert', 'del', 'rosario', 'pumanaw', 'edad', '83']
# Sentence after removing stopwords: ['suicide', 'cases', 'tumaas', 'noong', '2020', 'suporta', 'estudyante', 'hiniling', 'sen', 'gatchalian']
# Sentence after removing stopwords: ['8', 'arestado', 'bulacan', 'gumagawa', 'umano', 'ilegal', 'paputok']
# Sentence after removing stopwords: ['rehistradong', 'sim', 'cards', 'nasa', '133', '6m', 'rin']
# Sentence after removing stopwords: ['lalaking', 'nagnakaw', 'umano', 'bike', 'shop', 'arestado', 'qc']
# Sentence after removing stopwords: ['dalai', 'lama', 'humingi', 'paumanhin', 'pahalikin', 'batang', 'lalaki', 'kaniyang', 'dila']
# Sentence after removing stopwords: ['manilenyo', 'wagi', 'p16m', 'jackpot', 'prize', 'lotto']
# Sentence after removing stopwords: ['house', 'donate', 'karagdagang', 'p10m', 'humanitarian', 'aid', 'biktima', 'lindol', 'turkey']
# Sentence after removing stopwords: ['tulfo', 'hinimok', 'pcso', 'bigyan', 'health', 'benefits', 'small', 'time', 'bet', 'collectors']
# Sentence after removing stopwords: ['bong', 'go', 'umatras', 'pagtakbong', 'pangulo']
# Sentence after removing stopwords: ['di', 'kamag', 'anak', 'teves', 'sen', 'bato']
# Sentence after removing stopwords: ['9', 'sugatan', 'tumagilid', 'jeep', 'kamuning']
# Sentence after removing stopwords: ['ping', 'lacson', 'bongbong', 'marcos', 'leody', 'nakaboto', 'kani', 'voting', 'precinct']
# Sentence after removing stopwords: ['dengue', 'tag', 'init', 'babala', 'doh']
# Sentence after removing stopwords: ['suspek', 'pagpatay', 'dayuhang', 'taga', 'new', 'zealand', 'sumuko']
# Sentence after removing stopwords: ['kamara', 'inaprubahan', '2nd', 'reading', 'accompanying', 'bill', 'rbh', 'no', '6', 'nagpapatawag', 'con', 'con']
# Sentence after removing stopwords: ['pinatutumba', 'umano', 'teves', 'akusadong', 'pulis', 'nagkaharap']
# Sentence after removing stopwords: ['6', 'empleyado', 'teves', 'naabutan', 'raid', 'properties', 'nasa', 'kustodiya', 'pnp', 'cidg']
# Sentence after removing stopwords: ['cannahopefuls', 'isinusulong', 'gawing', 'legal', 'medical', 'marijuana']
# Sentence after removing stopwords: ['filipina', 'trafficking', 'victim', 'myanmar', 'nagbayad', 'ransom', 'bi']
# Sentence after removing stopwords: ['ufc', 'middleweight', 'world', 'title', 'nabawi', 'adesanya']
# Sentence after removing stopwords: ['mindore', 'nasungkit', 'p378m', 'ultralotto', '6', '58', 'jackpot']
# Sentence after removing stopwords: ['suspek', 'salilig', 'hazing', 'case', 'sumuko', '6', 'sinampahan', 'reklamo']
# Sentence after removing stopwords: ['lalaking', 'wanted', 'pananaksak', 'live', 'in', 'partner', 'zamboanga', 'sibugay', 'arestado', 'qc']
# Sentence after removing stopwords: ['comelec', 'susubaybayan', 'pagsunod', 'campaign', 'rules', '4', 'kandidato', 'special', 'election', 'cavite', '7th', 'district']
# Sentence after removing stopwords: ['4', 'sugatan', 'matapos', 'bumagsak', 'wawa', 'bridge', 'pangasinan']
# Sentence after removing stopwords: ['lalaking', 'amok', 'patay', 'pananaksak', 'tondo']
# Sentence after removing stopwords: ['bwelta', 'jv', 'ejercito', 'chikang', 'nakabuntis', 'wag', 'kayong', 'istorya', 'asawa', 'po', 'tao']
# Sentence after removing stopwords: ['48', 'patay', '40', 'sugatan', 'pananalasa', 'bagyong', 'paeng', '22', 'katao', 'nawawala']
# Sentence after removing stopwords: ['testing', 'quarantine', 'protocols', 'pilipinong', 'galing', 'ibang', 'bansa', 'niluwagan']
# Sentence after removing stopwords: ['who', 'di', 'tiyak', 'aalisin', 'covid', '19', 'public', 'health', 'emergency']
# Sentence after removing stopwords: ['twitter', 'pinalitan', 'logo', 'gaya', 'cryptocurrency', 'dogecoin']
# Sentence after removing stopwords: ['angkat', '330', '000', 'mt', 'bigas', 'iligal', 'ex', 'da', 'chief']
# Sentence after removing stopwords: ['covid', '19', 'kasama', 'top', '10', 'dahilan', 'pagkamatay', 'pilipinas']
# Sentence after removing stopwords: ['senador', 'lumagda', 'resolusyon', 'mariing', 'kumukondena', 'pagpaslang', 'kay', 'gov', 'degama']
# Sentence after removing stopwords: ['aeta', 'chieftain', 'missing', 'boracay', 'natagpuan']
# Sentence after removing stopwords: ['el', 'task', 'force', 'binuhay', 'da']
# Sentence after removing stopwords: ['babae', 'patay', 'matapos', 'umanong', 'saksakin', 'live', 'in', 'partner', 'caloocan', 'suspek', 'patay']
# Sentence after removing stopwords: ['babaeng', 'japanese', 'fugitive', 'arestado', 'opisina', 'bi', 'matapos', 'tangkaing', 'palawigin', 'tourist', 'visa']
# Sentence after removing stopwords: ['pagasa', 'lpa', 'asahang', 'papasok', 'bansa', 'magdadala', 'ulan']
# Sentence after removing stopwords: ['doh', 'hemophilia', 'lumapit', 'health', 'centers']
# Sentence after removing stopwords: ['marcos', 'nangakong', 'poprotektahan', 'kapakanan', 'ofws']
# Sentence after removing stopwords: ['hugot', 'isko', 'opo', 'lumaki', 'akong', 'busabos', 'ngunit', 'bastos']
# Sentence after removing stopwords: ['senate', 'probe', 'degamo', 'slay', 'di', 'magiging', 'kangaroo', 'court']
# Sentence after removing stopwords: ['marcos', 'tiwala', 'maaabot', 'bansa', 'rice', 'self', 'sufficiency', 'status', 'loob', 'dalawang', 'taon']
# Sentence after removing stopwords: ['rep', 'teves', 'humiling', 'makausap', 'pangulong', 'marcos']
# Sentence after removing stopwords: ['pagpapapako', 'krus', 'papayagan', 'san', 'fernando', 'pampanga', 'holy', 'week', '2023']
# Sentence after removing stopwords: ['dfa', 'handang', 'harapin', 'imbestigasyon', 'icc', 'war', 'on', 'drugs']
# Sentence after removing stopwords: ['alamin', 'myths', 'vs', 'facts', 'pagtutuli']
# Sentence after removing stopwords: ['nambugbog', '65', 'anyos', 'fil', 'new', 'york', 'city', 'nahuli']
# Sentence after removing stopwords: ['5', 'hinihinalang', 'drug', 'suspect', 'bicol', 'arestado', 'mahigit', 'p200k', 'halaga', 'shabu', 'nasabat']
# Sentence after removing stopwords: ['senador', 'isinusulong', 'pogo', 'zone']
# Sentence after removing stopwords: ['dfa', 'kinumpirmang', 'magpapadala', 'pilipinas', 'rescue', 'team', 'quake', 'hit', 'syria']
# Sentence after removing stopwords: ['suplay', 'bigas', 'sapat', 'di', 'import', 'da']
# Sentence after removing stopwords: ['marco', 'gumabao', 'ibinandera', 'relasyon', 'cristine', 'reyes', 'you', 'are', 'my', 'home', 'and', 'my', 'adventure', 'all', 'once']
# Sentence after removing stopwords: ['palasyo', 'tiniyak', 'handa', 'gobyerno', 'planong', 'transport', 'strike', 'lunes']
# Sentence after removing stopwords: ['pangulong', 'marcos', 'chinese', 'foreign', 'minister', 'qin', 'gang', 'nagkausap']
# Sentence after removing stopwords: ['97', 'lugar', 'bansa', 'nasa', 'alert', 'level', '4', 'doh']
# Sentence after removing stopwords: ['publiko', 'pinaalalahanang', 'sumunod', '5s', 'strategy', 'vs', 'dengue']
# Sentence after removing stopwords: ['cover', 'up', 'p6', '7', 'bilyong', 'shabu', 'haul', 'azurin']
# Sentence after removing stopwords: ['p85', 'srp', 'asukal', 'itatakda', 'da']
# Sentence after removing stopwords: ['bantag', 'dating', 'deputy', 'ricardo', 'zulueta', 'itinuturing', 'pugante', 'pnp']
# Sentence after removing stopwords: ['depositors', 'nawalan', 'pera', 'bank', 'hacking', 'hinikayat', 'magreklamo', 'bsp']
# Sentence after removing stopwords: ['pcg', 'haharangin', 'badjao', 'passenger', 'background', 'check', 'ipatutupad']
# Sentence after removing stopwords: ['dagdag', 'singil', 'meralco', 'generation', 'charge', 'uutay', 'utayin']
# Sentence after removing stopwords: ['ex', 'pdeg', 'chief', '48', 'kakasuhan', 'p6', '7', 'bilyong', 'shabu', 'cover', 'up']
# Sentence after removing stopwords: ["'tausug", "blend'", 'tea', 'layong', 'ipakilala', 'tausug']
# Sentence after removing stopwords: ['24', 'kolehiyo', 'unibersidad', 'pinayagan', 'magsagawa', 'limited', 'face', 'to', 'face', 'classes']
# Sentence after removing stopwords: ['libreng', 'sakay', 'meryenda', 'handog', 'tnt', 'lrt', '1', 'passengers', 'ika', '12', 'setyembre']
# Sentence after removing stopwords: ['teves', 'kinu', 'konsidera', 'umanong', 'posibleng', 'mastermind', 'pagpatay', 'kay', 'gov', 'degamo']
# Sentence after removing stopwords: ['47', 'opisyal', 'tauhan', 'pnp', 'mananagot', 'p6', '7', 'bilyong', 'shabu']
# Sentence after removing stopwords: ['pbbm', 'tiniyak', 'buong', 'suporta', 'atletang', 'sasabak', 'sea', 'games']
# Sentence after removing stopwords: ['solong', 'anak', 'nasawi', 'rin', 'umano', 'hazing', 'tau', 'gamma', 'phi', 'cebu']
# Sentence after removing stopwords: ['camarines', 'sur', 'polytechnic', 'colleges', 'naglabas', 'pahayag', 'ukol', 'plagiarized', 'speech', 'issue', 'magna', 'cum', 'laude', 'graduate']
# Sentence after removing stopwords: ['langis', 'lumubog', 'tanker', 'posibleng', 'tumatagas', 'rin']
# Sentence after removing stopwords: ['gang', 'india', 'pinaghahanap', 'matapos', 'nakawin', 'toneladang', 'dyebs', 'baka']
# Sentence after removing stopwords: ['lalaki', 'arestado', 'matapos', 'magpaputok', 'baril', 'iinuman', 'qc']
# Sentence after removing stopwords: ['singil', 'tubig', 'tataas', 'pagpasok', 'taong', '2023']
# Sentence after removing stopwords: ['paglipat', 'pnp', 'custody', 'gunman', 'percy', 'lapid', 'slay', 'aprub', 'korte']
# Sentence after removing stopwords: ['pnp', 'naka', 'heightened', 'alert']
# Sentence after removing stopwords: ['2', 'online', 'sellers', 'covid', '19', 'test', 'kits', 'arestado', 'maynila']
# Sentence after removing stopwords: ['frat', 'member', 'humingi', 'tawad', 'kay', 'john', 'matthew', 'salilig', "'sorry", "talaga'"]
# Sentence after removing stopwords: ['bangkay', 'college', 'student', 'natagpuan', 'cavite']
# Sentence after removing stopwords: ['pbbm', 'nakatanggap', 'very', 'good', 'net', 'satisfaction', 'rating', 'sws']
# Sentence after removing stopwords: ['enrique', 'gil', 'nananatiling', 'kapamilya', 'pumirma', 'exclusive', 'contract', 'abs', 'cbn']
# Sentence after removing stopwords: ['look', 'dating', 'gabinete', 'noynoy', 'nagpakuha', 'huling', 'larawan', 'kasama', 'labi', 'namayapang', 'pangulo']
# Sentence after removing stopwords: ['ilang', 'senador', 'wi', 'nelcome', 'planong', 'expansion', 'philhealth', 'hemodialysis', 'coverage']
# Sentence after removing stopwords: ['araw', 'pagkabuhay', 'gamitin', 'magbago', 'magpakabuti', 'marcos']
# Sentence after removing stopwords: ['manila', 'lgu', 'pinag', 'aaralang', 'ibalik', 'face', 'mask', 'rule']
# Sentence after removing stopwords: ['nakakaaliw', 'tnt', 'video', 'sim', 'registration', 'viral']
# Sentence after removing stopwords: ['maynilad', 'nagbabala', 'mas', 'matagal', 'water', 'interruption', 'simula', 'april', '1']
# Sentence after removing stopwords: ['gobyerno', 'makipagtulungan', 'fbi', 'pagpapauwe', 'kay', 'cong', 'teves']
# Sentence after removing stopwords: ['ex', 'pnp', 'deputy', 'chief', 'for', 'ops', 'pumalag', 'kay', 'abalos', 'p6', '7', 'bilyon', 'shabu', 'cover', 'up']
# Sentence after removing stopwords: ['pagtaas', 'presyo', 'produktong', 'baboy', 'iniimbestigahan', 'gobyerno']
# Sentence after removing stopwords: ['octa', 'mas', 'maraming', 'pinoy', 'tiwala', 'kay', 'pangulong', 'bongbong']
# Sentence after removing stopwords: ['anti', 'taray', 'bill', 'government', 'workers', 'isinulong', 'senado']
# Sentence after removing stopwords: ['hosting', 'pilipinas', 'fiba', 'asia', 'cup', 'tuloy']
# Sentence after removing stopwords: ['7', 'key', 'bilateral', 'agreements', 'nakatakdang', 'lagdaan', 'japan', 'visit', 'pbbm']
# Sentence after removing stopwords: ['marcos', 'inatasan', 'dswd', 'ituloy', 'calibrate', '4ps']
# Sentence after removing stopwords: ['daan', 'daang', 'residente', 'lopez', 'quezon', 'inilikas', "'amang'"]
# Sentence after removing stopwords: ['dpwh', 'magsasagawa', 'weekend', 'road', 'reblocking']
# Sentence after removing stopwords: ['criteria', 'a4', 'covid', '19', 'vaccination', 'simple']
# Sentence after removing stopwords: ['ayuda', 'tsuper', 'pasahero', 'ipaglalaban', 'dotr', 'ltfrb', 'tugade']
# Sentence after removing stopwords: ['opisyal', 'sugar', 'regulatory', 'administration', 'nagbitiw', 'puwesto']
# Sentence after removing stopwords: ['lingkod', 'kapamilya', 'nakiisa', 'blood', 'donation', 'taytay']
# Sentence after removing stopwords: ['marcos', 'pinatawag', 'chinese', 'envoy', 'upang', 'ipahayag', 'pagkabahala', 'china', 'vs', 'pcg', 'filipino', 'fishermen', 'wps']
# Sentence after removing stopwords: ['number', 'coding', 'muling', 'ipinatutupad', 'metro', 'manila', 'disyembre', '1']
# Sentence after removing stopwords: ['p4', 'b', 'halaga', 'hinihinalang', 'shabu', 'nasa', 'tea', 'bag', 'nasabat', 'baguio', 'city']
# Sentence after removing stopwords: ['mambabatas', 'isinusulong', 'pagsasama', 'electric', 'motorcycle', 'bagong', 'eo', 'nagpapataw', 'zero', 'import', 'tariff', 'e', 'motorcycles']
# Sentence after removing stopwords: ['kaso', 'dengue', 'quezon', 'city', 'tumaas', '176', 'percent']
# Sentence after removing stopwords: ['sc', 'pinagtibay', 'pagiging', 'legal', 'train', 'law']
# Sentence after removing stopwords: ['philippines', 'us', 'balikatan', 'arangkada']
# Sentence after removing stopwords: ['ilang', 'lugar', 'luzon', 'visayas', 'isinailalim', 'signal', 'no', '1', 'bagyong', 'amang']
# Sentence after removing stopwords: ['james', 'yap', 'pagsabak', 'politika', 'hamon', 'baguhang', 'matitinag']
# Sentence after removing stopwords: ['95', '300', 'katao', 'nasalanta', "'amang'", 'ndrrmc']
# Sentence after removing stopwords: ['lalaki', 'patay', 'matapos', 'pagbabarilin', 'nakaalitan', 'umanong', 'tnvs', 'rider']
# Sentence after removing stopwords: ['allowance', 'guro', 'darating', 'barangay', 'sk', 'elections', 'tataasan', 'comelec']
# Sentence after removing stopwords: ['p150', 'umento', 'sahod', 'private', 'sector', 'iginiit']
# Sentence after removing stopwords: ['isyu', 'papel', 'lisensiya', 'ikinadismaya', 'motorista']
# Sentence after removing stopwords: ['bongbong', 'marcos', 'negatibo', 'cocaine']
# Sentence after removing stopwords: ["'isa", "utak'", 'marvin', 'miranda', 'pinakakasuhan', '9', 'counts', 'murder', 'degamo', 'slay']
# Sentence after removing stopwords: ['ilang', 'mambabatas', 'hiniling', 'concerned', 'agencies', 'ganap', 'ipatupad', 'the', 'centenarians', 'act', 'of', '2016']
# Sentence after removing stopwords: ['suporta', 'electric', 'vehicles', 'sagot', 'tumataas', 'presyo', 'langis', 'umiigting']
# Sentence after removing stopwords: ['cpp', 'kinumpirma', 'pagkamatay', 'nina', 'benito', 'wilma', 'tiamzon', "'tinorture'", 'diumano']
# Sentence after removing stopwords: ['speaker', 'romualdez', "'di", 'hahadlangan', 'imbestigasyon', 'ethics', 'panel', 'kay', 'rep', 'arnie', 'teves']
# Sentence after removing stopwords: ['hpg', 'chief', 'nagbitiw', 'matapos', 'sibakin', 'puwesto', 'sariling', 'anak', 'nasangkot', 'kontrobersiya']
# Sentence after removing stopwords: ['sec', 'remulla', 'optimismo', 'malapit', 'maresolba', 'kaso', 'pagpatay', 'kay', 'gov', 'degamo']
# Sentence after removing stopwords: ['taong', 'transition', 'period', 'i', 'phase', 'out', 'pogo', 'sapat', 'ayon', 'senador']
# Sentence after removing stopwords: ['pang', 'kaso', 'vs', 'de', 'dedesisyunan']
# Sentence after removing stopwords: ['batang', 'nasa', 'loob', 'delivery', 'box', 'motorsiklo', 'nakunan', 'video']
# Sentence after removing stopwords: ['pink', 'netizens', 'nanawagan', 'isama', 'monsour', 'del', 'rosario', 'senatorial', 'slate', 'leni', 'kiko', 'tandem']
# Sentence after removing stopwords: ['bagyong', 'odette', 'lalong', 'lumalakas', 'signal', 'no', '2', 'itinaas', 'ilang', 'parte', 'surigao']
# Sentence after removing stopwords: ['no', 'permit', 'no', 'exam', 'ban', 'magpapasara', 'maraming', 'pribadong', 'eskwelahan']
# Sentence after removing stopwords: ['doh', 'iginiit', 'pagsusuot', 'face', 'mask', 'christmas', 'gatherings', 'events']
# Sentence after removing stopwords: ['madre', 'itinuturing', 'pinakamatandang', 'tao', 'mundo', 'pumanaw', 'edad', '118']
# Sentence after removing stopwords: ['p162m', 'jackpot', 'grand', 'lotto', '6', '55', 'nasungkit']
# Sentence after removing stopwords: ['malakanyang', 'nalungkot', 'pagbagsak', 'pilipinas', 'world', 'happiness', 'report', 'ranking']
# Sentence after removing stopwords: ['deped', 'palalakasin', 'numeracy', 'literacy', 'programs', 'revised', 'k', 'to', '12', 'program']
# Sentence after removing stopwords: ['harry', 'roque', 'naospital', 'covid', '19']
# Sentence after removing stopwords: ['padilla', 'nagbanta', 'aalis', 'pdp', 'susuportahan', 'partido', 'cha', 'cha']
# Sentence after removing stopwords: ['2', 'kabataan', 'inaresto', 'magprotesta', 'vs', 'balikatan', 'edca', 'us', 'embassy', 'pnp']
# Sentence after removing stopwords: ['e', 'travel', 'system']
# Sentence after removing stopwords: ['panukalang', 'rightsizing', 'pamahalaan', 'lusot', 'kamara']
# Sentence after removing stopwords: ['milyun', 'milyong', 'pisong', 'halaga', 'droga', 'umano', 'nasabat', 'condo', 'unit', 'mandaluyong', 'syrian', 'national', 'arestado']
# Sentence after removing stopwords: ['sec', 'gatchalian', 'pinag', 'iingat', 'publiko', 'vs', 'text', 'scam', 'unclaimed', 'senior', 'allowances']
# Sentence after removing stopwords: ['6', '6', 'magnitude', 'lindol', 'yumanig', 'samar', 'bicol']
# Sentence after removing stopwords: ['bi', 'naalarma', 'kaugnay', 'talamak', 'totoo', 'ilegal', 'nakuhang', 'philippine', 'passport']
# Sentence after removing stopwords: ['83', 'pilipino', 'nasa', 'death', 'row', 'abroad', 'ayon', 'dfa']
# Sentence after removing stopwords: ['52', 'pinoy', "'disapprove'", 'pagtugon', 'marcos', 'jr', 'inflation', 'pulse', 'asia']
# Sentence after removing stopwords: ['security', 'officers', 'naia', 'nahuli', 'cam', 'umano', 'pera', 'papaalis', 'turistang', 'thai']
# Sentence after removing stopwords: ['magkapatid', 'senior', 'citizen', 'natagpuang', 'patay', 'maynila', 'suspek', 'arestado']
# Sentence after removing stopwords: ['csc', 'chief', 'nanawagan', 'pagkakaisa', 'gender', 'mainstreaming', 'asean', 'region']
# Sentence after removing stopwords: ['tnvs', 'driver', 'stephen', 'speaks', 'pinalusot', 'umano', 'violation', 'matapos', 'magpa', 'selfie', 'banda', 'enforcer', 'mmda', 'iimbestiga']
# Sentence after removing stopwords: ['awtorisadong', 'koleksyon', 'prize', 'fund', 'taxes', 'umabot', 'p4', 'bilyon']
# Sentence after removing stopwords: ['viral', 'pagsagasa', 'truck', 'enforcer', 'nagmamando', 'trapiko', 'quezon', 'city', 'iimbestigahan']
# Sentence after removing stopwords: ['bagsik', 'neneng', 'ramdam', 'rin', 'pinas', 'ilang', 'klase', 'northern', 'luzon', 'suspendido']
# Sentence after removing stopwords: ['pulse', 'asia', '6', '10', 'pinoy', 'ayaw', 'magpabakuna', 'covid', '19']
# Sentence after removing stopwords: ['pnp', 'chief', 'itinanggi', "umano'y", 'cover', 'up', 'manila', 'drug', 'raid']
# Sentence after removing stopwords: ['grupo', 'pumalag', 'angkat', 'buffer', 'stock', 'nfa', 'rice']
# Sentence after removing stopwords: ['49', 'pilipino', 'naniniwalang', 'gaganda', 'kalidad', 'pamumuhay', 'susunod', '12', 'buwan', 'sws']
# Sentence after removing stopwords: ['pagasa', 'bagyo', 'asahan', 'kalat', 'kalat', 'ulan', 'ilang', 'lugar']
# Sentence after removing stopwords: ['jane', 'de', 'leon', 'binanatan', 'netizen', 'binuhay', 'pagiging', 'kakampink', 'let', 's', 'boycott', 'darna']
# Sentence after removing stopwords: ['amnesty', 'international', 'nanawagan', 'independent', 'investigation', 'lapid', 'slay', 'case']
# Sentence after removing stopwords: ['bulkang', 'taal', 'nakapagtala', '55', 'volcanic', 'quakes']
# Sentence after removing stopwords: ['dating', 'kitchen', 'helper', 'wagi', 'p75', '2m', 'grand', 'lotto', '6', '55']
# Sentence after removing stopwords: ['maynilad', 'ilang', 'bahagi', 'ncr', 'cavite', 'mawawalan', 'tubig', 'april', '23']
# Sentence after removing stopwords: ['lpa', 'magpapaulan', 'vismin', 'mainit', 'paparating', 'pagasa']
# Sentence after removing stopwords: ['apor', 'nasa', 'granular', 'lockdown', 'payagang', 'makapagtrabaho', 'ayon', 'kay', 'marcos']
# Sentence after removing stopwords: ['korte', 'lugar', 'isasailalim', 'gcq', 'bubuksan', 'simula', 'mayo', '17']
# Sentence after removing stopwords: ['marcos', 'target', '2027', 'rice', "'self", "sufficiency'", 'posible', 'liberalisasyon', 'tatalikuran', 'grupo']
# Sentence after removing stopwords: ['government', 'agencies', 'aaksyon', 'reklamo', 'loob', 'tatlong', 'araw', 'paiimbestigahan', 'arta', 'ombudsman']
# Sentence after removing stopwords: ['panoorin', 'karen', 'meets', 'kaladkaren']
# Sentence after removing stopwords: ['water', 'level', 'angat', 'dam', '6', 'patuloy', 'pagbaba']
# Sentence after removing stopwords: ['dayuhang', 'pasahero', 'naia', 'nawalan', 'p50k', 'naibalik', 'agad', 'airport', 'staff']
# Sentence after removing stopwords: ['lalaking', 'nagpapanggap', 'koneksyon', 'makati', 'city', 'hall', 'huli', 'swindling']
# Sentence after removing stopwords: ['4', 'central', 'luzon', 'areas', 'nagtala', 'pinakamataas', 'bagong', 'kaso', 'covid', '19']
# Sentence after removing stopwords: ['one', 'strike', 'policy', 'magdudulot', 'blacklisting', 'persona', 'non', 'grata', 'taong', 'nagsasagawa', 'hazing']
# Sentence after removing stopwords: ['speech', 'japan', 'prime', 'minister', 'kishida', 'hinagisan', 'smoke', 'bomb']
# Sentence after removing stopwords: ['globe', 'libreng', 'tawag', 'libreng', 'wifi', 'nakahanda', 'bagyong', 'kiko']
# Sentence after removing stopwords: ['alamin', 'presyo', 'bulaklak', 'dangwa', 'market', 'kakaibang', 'pangregalo', 'valentine', 's', 'day']
# Sentence after removing stopwords: ['rider', 'patay', 'pamamaril', 'ntilde', 'aque', 'insidente', 'nahuli', 'cam']
# Sentence after removing stopwords: ['lrt', 'papayagan', 'pagsakay', 'pets', 'simula', 'feb', '1']
# Sentence after removing stopwords: ['person', 'of', 'interest', 'idinawit', 'pagkamatay', 'john', 'mathew', 'salilig', 'natagpuang', 'patay']
# Sentence after removing stopwords: ['dmw', 'magpapadala', 'fact', 'finding', 'team', 'kuwait', 'kasunod', 'brutal', 'pagkamatay', 'jullebee', 'ranara']
# Sentence after removing stopwords: ['dating', 'pangulong', 'marcos', 'tulay', 'iibigan', 'magulang', 'greco', 'belgica']
# Sentence after removing stopwords: ['17', 'anyos', 'dalagita', '10', 'araw', 'guho', 'nasagip', 'turkey']
# Sentence after removing stopwords: ['sec', 'abalos', 'tiniyak', 'buong', 'suporta', 'bagong', 'hepe', 'pnp', 'pgen', 'benjamin', 'acorda']
# Sentence after removing stopwords: ['mahigit', 'daang', 'grupo', 'indibidwal', 'umapela', 'senado', 'umapela', 'rejection', 'rcep']
# Sentence after removing stopwords: ['paglikas', 'pilipino', 'sudan', 'inaayos', 'pamahalaan']
# Sentence after removing stopwords: ['manny', 'pacquiao', 'chavit', 'singson', 'nagkabati', 'because', 'friendship', 'is', 'stronger', 'than', 'politics']
# Sentence after removing stopwords: ['pagpapatupad', 'bagong', 'e', 'travel', 'system', 'lalawakan', 'simula', 'abril', '15']
# Sentence after removing stopwords: ['da', 'nagtakda', 'p125', 'kada', 'kilo', 'srp', 'imported', 'pulang', 'sibuyas']
# Sentence after removing stopwords: ['babaeng', 'pumalag', 'snatcher', 'naagaw', 'motor']
# Sentence after removing stopwords: ['dalawang', 'karagdagang', 'reklamo', 'suspek', 'salilig', 'case', 'submitted', 'for', 'resolution', 'doj']
# Sentence after removing stopwords: ['umano', 'y', 'korupsyon', 'dswd', 'doe', 'ibinunyag', 'pacquiao']
# Sentence after removing stopwords: ['us', 'australian', 'military', 'planes', 'nasa', 'pinas', 'balikatan']
# Sentence after removing stopwords: ['nanuhol', 'yarn', 'traffic', 'violation', 'stephen', 'speaks', 'iimbestigahan', 'mmda']
# Sentence after removing stopwords: ['covid', '19', 'positivity', 'rate', 'ncr', 'biglang', 'tumaas', 'ngayong', 'holy', 'week', 'octa']
# Sentence after removing stopwords: ['paeng', 'tapos', 'manalasa', 'bansa', 'pang', 'bagyo', 'nagbabadya']
# Sentence after removing stopwords: ['utang', 'gobyerno', 'lumobo', 'p13', '7t', 'noong', 'enero']
# Sentence after removing stopwords: ['kwento', 'marc', 'logan', 'video', "'tsismosong'", 'aso', 'pusa']
# Sentence after removing stopwords: ['da', 'usec', 'panganiban', 'itinalagang', 'oic', 'sra']
# Sentence after removing stopwords: ['dnd', 'pumalag', 'banta', 'chinese', 'envoy', 'lagay', 'ofws', 'taiwan']
# Sentence after removing stopwords: ['hong', 'raffle', '500k', 'plane', 'tickets', 'libreng', 'vouchers']
# Sentence after removing stopwords: ['7', 'pulis', 'patay', '22', 'sugatan', 'karambola', '3', 'sasakyan', 'misamis', 'oriental']
# Sentence after removing stopwords: ['carlo', 'biado', 'kampeon', '2021', 'us', 'open', 'pool']
# Sentence after removing stopwords: ['panininghal', 'harry', 'roque', 'doktor', 'ikinadismaya', 'nina', 'angel', 'ogie']
# Sentence after removing stopwords: ['inflation', 'nitong', 'marso', 'bumaba', '7', '6', '8', '6', 'noong', 'pebrero', 'psa']
# Sentence after removing stopwords: ['lugi', 'occidental', 'mindoro', 'power', 'crisis', 'milyon', 'milyon']
# Sentence after removing stopwords: ['kfc', 'branch', 'pasig', 'ipinasara', 'reklamo', 'mayor', 'vico', 'sotto', 'grabe', 'yung', 'kapal', 'sebo']
# Sentence after removing stopwords: ['imbentaryo', 'bigas', 'bansa', 'bumagsak', 'noong', 'nakaraang', 'buwan', 'psa']
# Sentence after removing stopwords: ['5', 'house', 'leaders', 'naghain', 'panukala', 'bigyan', 'kapangyarihan', 'pbbm', 'suspendihin', 'philhealth', 'rate', 'hikes']
# Sentence after removing stopwords: ['duterte', 'makikipag', 'debate', 'kay', 'carpio']
# Sentence after removing stopwords: ['lto', 'driver', 's', 'license', 'mae', 'expire', 'simula', 'april', '24', 'palalawigin', 'multa', 'late', 'penalty', 'di', 'muna', 'sisingilin']
# Sentence after removing stopwords: ['mangingisda', 'magsasaka', 'inalerto', 'da', 'kay', 'amang']
# Sentence after removing stopwords: ['kampo', 'pimentel', 'pacquiao', 'susuportahan', 'sakaling', 'tumakbong', 'presidente', '2022']
# Sentence after removing stopwords: ['toni', 'binanatan', 'netizens', 'interview', 'kay', 'bongbong', 'such', 'a', 'disappointment']
# Sentence after removing stopwords: ['sec', 'remulla', 'tiniyak', 'makakaligtas', 'imbestigasyon', 'pamamaslang', 'kay', 'gov', 'degamo', '8']
# Sentence after removing stopwords: ['4', '10', 'detainees', 'tumakas', 'pasay', 'jail', 'nasakote']
# Sentence after removing stopwords: ['patong', 'patong', 'trabaho', 'public', 'school', 'teachers', 'solusyonan']
# Sentence after removing stopwords: ['26', 'lugar', 'puerto', 'galera', 'nakitaan', 'langis', 'grasa']
# Sentence after removing stopwords: ['30', '3', 'million', 'philsys', 'ids', 'naipadala', 'psa']
# Sentence after removing stopwords: ['pagasa', 'lpa', 'patuloy', 'lumalapit', 'mindanao', 'mababa', 'tsansa', 'bagyo']
# Sentence after removing stopwords: ['ex', 'bucor', 'chief', 'bantag', 'zulueta', 'pina', 'aaresto', 'korte', 'kaugnay', 'lapid', 'slay', 'case']
# Sentence after removing stopwords: ['sunod', 'sunod', 'atake', 'gov', 't', 'officials', 'isolated', 'cases', 'ayon', 'pnp']
# Sentence after removing stopwords: ['unidentified', 'flying', 'object', 'himpapawid', 'canada', 'pinabagsak', 'us', 'fighter', 'jet']
# Sentence after removing stopwords: ['batang', 'aaral', 'nagiging', 'zombie', 'distance', 'learning', 'system', 'sen', 'imee', 'marcos']
# Sentence after removing stopwords: ['prc', 'licensure', 'exam', 'mayo', 'hunyo', 'tuloy']
# Sentence after removing stopwords: ['sakay', 'bumagsak', 'cessna', 'plane', 'bicol', 'kumpirmadong', 'nasawi', 'mdash', 'mayor']
# Sentence after removing stopwords: ['manlalakbay', '7', 'bansa', 'africa', 'bawal', 'pumasok', 'pinas']
# Sentence after removing stopwords: ['dswd', 'pinalawig', 'cash', 'for', 'work', 'program', 'oriental', 'mindoro', 'apektado', 'oil', 'spill']
# Sentence after removing stopwords: ['water', 'crisis', 'hinaharap', 'umano', 'bansa', 'ayon', 'kay', 'pangulong', 'marcos']
# Sentence after removing stopwords: ['grupo', 'kinastigo', "'pang", "iismol'", 'afp', 'epekto', 'balikatan', 'pangingisda']
# Sentence after removing stopwords: ['miss', 'earth', '2022', 'suportado', 'tariff', 'breaks', 'electric', 'vehicles']
# Sentence after removing stopwords: ['paggamit', 'sara', 'duterte', 'chopper', 'araw', 'araw', 'fake', 'news', 'daw', 'ayon', 'vp', 'spokesperson']
# Sentence after removing stopwords: ['suspek', 'tila', 'nilito', 'umano', 'hinggil', 'totoong', 'target', 'degamo', 'slay', 'case', 'pulisya']
# Sentence after removing stopwords: ['house', 'sinimulan', 'plenary', 'deliberations', 'panukalang', 'cha', 'cha']
# Sentence after removing stopwords: ['doh', 'nakapag', 'detect', '671', 'bagong', 'kaso', 'omicron', 'subvariants']
# Sentence after removing stopwords: ['san', 'beda', 'university', 'kakampink', 'rin']
# Sentence after removing stopwords: ['klase', 'occidental', 'mindoro', 'walangpasok', '3', 'araw']
# Sentence after removing stopwords: ['psa', 'nakapagbigay', 'mahigit', '40', 'million', 'national', 'id', 'ngayong', 'enero']
# Sentence after removing stopwords: ['ama', 'cambodia', 'tinamaan', 'bird', 'flu', 'batang', 'babae', 'patay', 'w', 'h']
# Sentence after removing stopwords: ['ilang', 'pulis', 'umano', 'ginamit', 'spotters', 'pagpatay', 'negros', 'oriental']
# Sentence after removing stopwords: ['tigil', 'pasada', 'jeep', 'itutuloy', 'march', '6', '12']
# Sentence after removing stopwords: ['pilot', 'testing', 'balik', 'eskuwelahan', 'inaprubhan', 'pangulong', 'duterte']
# Sentence after removing stopwords: ['2', 'mataas', 'opisyal', 'gobyerno', 'ipapapatay', 'rep', 'teves']
# ...
# Sentence after removing stopwords: ['ulan', 'tumila', 'tapos', 'biglang', 'umaraw', 'climate', 'change', 'iyun', 'iyun', 'climate', 'change', 'natin', 'gawing', 'biro', 'di', 'naman', 'seryoso']
# Sentence after removing stopwords: ['groom', 'naghahatid', 'invitations', 'nalalapit', 'kasal', 'binawian', 'buhay', 'matapos', 'maaksidente']
# Sentence after removing stopwords: ['lalaking', 'nagbebenta', 'sponge', 'loob', '13', 'years', 'graduate', 'kolehiyo']
# Sentence after removing stopwords: ['naka', 'bike', 'delivery', 'rider', 'tinulungan', "'dating", 'batang', 'kalye', 'ngayo', 'y', 'tumutulong', "na'"]
# Sentence after removing stopwords: ['daga', 'nakapasok', 'atm', 'machine', 'nginatngat', 'pera', 'loob']
# Sentence after removing stopwords: ['5', 'rescuers', 'bulacan', 'nasawi', 'tungkulin', 'kinilalang', 'bayani', 'paparangalan']
# Sentence after removing stopwords: ['dennis', 'padilla', 'umaming', 'nagkasala', 'gustong', 'makapiling', 'anak', 'marjorie']
# Sentence after removing stopwords: ['bank', 'mngr', 'kilalang', 'bangko', 'inireklamo', 'unauthorized', 'withdrawals', 'bank', 'accounts', 'kliyente']
# Sentence after removing stopwords: ['ruffa', 'binahagi', 'muling', 'pagkakausap', 'yilmaz', 'yilmaz', 'lang', 'yung', 'lalaki', 'iniiyakan', 'rin']
# Sentence after removing stopwords: ['saging', 'halos', 'kasing', 'haba', 'braso', 'tao', 'natagpuan', 'pangasinan']
# Sentence after removing stopwords: ['retired', 'manager', 'tropical', 'hut', 'masayang', 'nagdiwang', "'father's", "day'", 'dating', 'pinagtatrabahuhan']
# Sentence after removing stopwords: ['hala', 'nlrc', 'ipatanggal', 'senado', 'sen', 'tulfo', 'taong', 'bayan', 'people', 'power', 'daw']
# Sentence after removing stopwords: ['pasang', 'awa', 'laging', 'bagsak', 'estudyante', 'topnotcher', 'nursing', 'board', 'exam']
# Sentence after removing stopwords: ['grabe', 'nangyari', 'turkey', 'lang', 'feb', '6', '2023', 'pray', 'po', 'nating', 'lagi', 'po', 'handa', 'iingat']
# Sentence after removing stopwords: ['binata', 'winakasan', 'buhay', 'pananakot', 'inutangan', 'loan', 'apps']
# Sentence after removing stopwords: ['anak', 'basurero', 'ipinagmalaki', 'amang', 'napagtapos', 'aaral']
# Sentence after removing stopwords: ['nakaraos', 'proud', 'repeater', 'ganap', 'civil', 'engineer']
# Sentence after removing stopwords: ['dj', 'loonyo', 'binuweltahan', 'janine', 'berdin', 'matapos', 'idawit', 'pangalan', 'larawan', "'airport'", 'meme']
# Sentence after removing stopwords: ['kat', 'alano', 'pinapatamaan', 'people', 'will', 'cancel', 'you', 'for', 'cake', 'but', 'celebrate', 'you', 'for', 'rap3']
# Sentence after removing stopwords: ['ina', 'negros', 'occidental', 'parehas', 'centenarian']
# Sentence after removing stopwords: ['raffy', 'tulfo', 'binatikos', 'netizen', 'matapos', 'maliitin', '16m', 'bumoto', 'kay', 'pangulong', 'duterte']
# Sentence after removing stopwords: ['batikang', 'aktres', 'tinalbugan', 'kasabayan', 'showbiz', 'edad', '40', 'nabuntis']
# Sentence after removing stopwords: ['matandang', 'lalaki', 'niloko', 'kinuha', 'atm', 'pension', 'puno', 'natutulog']
# Sentence after removing stopwords: ['teacher', 'minura', 'estudyanteng', 'tinutulungan', 'makapasa', 'naglabas', 'sama', 'loob']
# Sentence after removing stopwords: ['the', 'ren', 'ai', 'reef', 'is', 'part', 'of', 'china', 's', 'nansha', 'islands', 'on', 'february', '6', 'a', 'philippine', 'coast', 'guard', 'vessel', 'intruded', 'into', 'the', 'waters', 'off', 'the', 'ren', 'ai', 'reef', 'without', 'chinese', 'permission', 'in', 'accordance', 'with', 'china', 's', 'domestic', 'law', 'and', 'international', 'law', 'including', 'the', 'united', 'nations', 'convention', 'on', 'the', 'law', 'of', 'the', 'sea', 'the', 'china', 'coast', 'guard', 'ship', 'upheld', 'china', 's', 'sovereignty', 'and', 'maritime', 'order', 'and', 'acted', 'in', 'a', 'professional', 'and', 'restrained', 'way', 'source', 'china', 'ministry', 'of', 'foreign', 'affairs', 'official', 'website', 'foreign', 'ministry', 'spokesperson', 'wang', 'wenbin', 's', 'regular', 'press', 'conference', 'on', 'february', '13', '2023', 'feb', '13', '2023']
# Sentence after removing stopwords: ['plantita', 'lumabo', 'mata', 'matapos', 'matalsikan', 'dagta', 'halamang']
# Sentence after removing stopwords: ['lolit', 'solis', 'kinuwestiyon', 'kontribusyon', 'nina', 'philip', 'salvador', 'james', 'yap', 'anak', 'ngayong', 'pinagdaraanan', 'kalusugan', 'kris', 'aquino']
# Sentence after removing stopwords: ['19', 'anyos', 'ina', 'bitbit', 'anak', 'nagtatrabaho', 'taga', 'deliver', 'pagkain']
# Sentence after removing stopwords: ['the', 'maggie', 'dela', 'riva', 'story', 'maimpluwensyang', 'tao', 'tinapos', 'buhay']
# Sentence after removing stopwords: ['ex', 'commissioner', 'rowena', 'guanzon', 'resbak', 'kay', 'ruffa', 'that', 'ruffa', 'gutierrez', 'must', 'learn', 'to', 'say', "'congresswoman'"]
# Sentence after removing stopwords: ['kuya', 'kim', 'ipinagmalaki', 'kaniyang', 'anak', 'ngayong', 'lisensyadong', 'piloto']
# Sentence after removing stopwords: ['ina', 'dismayado', 'sinapit', 'anak', 'labis', 'paggamit', 'cellphone', "'i", 'really', 'felt', 'guilty', 'as', 'a', "mom'"]
# Sentence after removing stopwords: ['lola', 'patuloy', 'pagtitinda', 'mais', 'umulan', 'man', 'umaraw']
# Sentence after removing stopwords: ['lalaki', 'nakapagpatayo', 'magandang', 'bahay', 'halagang', '50', '000', 'pesos', 'aircon']
# Sentence after removing stopwords: ['kylie', 'padilla', 'to', 'robin', 'mahal', 'mahal', 'tatay', 'pilipinas', 'mahal', 'nya', 'tao']
# Sentence after removing stopwords: ['akala', 'talaga', 'magaling', 'fbi', 'di', 'hanapin', 'yung', 'wanted', 'pastor', 'apollo', 'quiboloy', 'source', 'krizette', 'laureta', 'chu', 's', 'official', 'facebook', 'page', 'akala', 'talaga', 'magaling', 'fbi', 'dec', '11', '2022']
# Sentence after removing stopwords: ['empleyado', 'nagpasa', 'resignation', 'letter', 'kinaaliwan', 'social', 'media']
# Sentence after removing stopwords: ['amang', 'maigalaw', 'kalahati', 'katawan', 'itinataguyod', 'pamilya', 'mekaniko']
# Sentence after removing stopwords: ['wouldn', 't', 'it', 'be', 'easier', 'confidential', 'funds', 'ibibigay', 'eskwelahan', 'nangangailangan', 'bubong', 'pondo', 'eh', 'you', 'have', 'to', 'remember', 'maglalagay', 'eskwelahan', 'lugar', 'naka', 'earmark', 'yan', 'bagyo', 'dun', 'karatig', 'bayan', 'natamaan', 'bagyo', 'natamaan', 'flash', 'flood', 'nangangailangan', 'source', 'senate', 'of', 'the', 'philippines', 'transcription', 'of', 'senate', 'president', 'juan', 'miguel', 'migz', 'zubiri', 's', 'press', 'conference', 'nov', '7', '2022']
# Sentence after removing stopwords: ['turista', 'boracay', 'siningil', 'umano', 'p16', '000', 'hair', 'braiding']
# Sentence after removing stopwords: ['2', 'anyos', 'bata', 'patay', 'matapos', 'isuksok', 'kutsara', 'extension', 'cord']
# Sentence after removing stopwords: ['magkapatid', 'paslit', 'binalikan', 'nanay', 'bibili', 'lang', 'daw', 'payong']
# Sentence after removing stopwords: ['mas', 'mababa', '16', 'inutang', '2022', 'kumpara', 'taong', '2021', 'patunay', 'epektibo', 'polisiya', 'pangangasiwa', 'budget', 'pagpapababa', 'pagdepende', 'natin', 'utang', 'matugunan', 'pangangailangan', 'natin', 'bansa', 'source', 'bongbong', 'marcos', 'official', 'facebook', 'page', 'mas', 'mababa', '16', 'inutang', 'march', '13', '2023']
# Sentence after removing stopwords: ['customer', 'sikat', 'restaurant', 'muntik', 'makakain', 'ipis']
# Sentence after removing stopwords: ['lola', 'nakapagtapos', 'edad', '62', 'pinagsasabay', 'aaral', 'aalaga', 'apo', 'pagtitinda']
# Sentence after removing stopwords: ['babala', 'magulang', 'bata', 'dinanas', 'masamang', 'epekto', 'sobrang', 'pagamit', 'gadgets']
# Sentence after removing stopwords: ['dating', 'tampulan', 'tukso', 'laging', 'umiiyak', 'paguwi', 'galing', 'eskwela', "modelo't", 'sariling', 'negosyo']
# Sentence after removing stopwords: ['simple', 'praktikal', 'kasal', 'magkasintahang', 'hikers', 'umabot', '4', 'libong', 'piso']
# Sentence after removing stopwords: ['kasamahan', 'jovelyn', 'galleno', 'simbahan', 'sinabing', 'umano', 'nakasakay', 'innova', 'nitong', 'agosto', '16']
# Sentence after removing stopwords: ['incoming', 'grade', '12', 'student', 'naghahanap', 'aampon', 'magpapa', 'aral']
# Sentence after removing stopwords: ['pinoy', 'memories', 'inabutan', 'mo', 'ba', 'popular', 'darigold', 'milk']
# Sentence after removing stopwords: ['mamahaling', 'crystal', 'natagpuan', 'puno', 'balete', 'antique']
# Sentence after removing stopwords: ['anna', 'feliciano', 'tuwang', 'tuwa', 'tinanggap', 'sorpresang', 'brand', 'new', 'car', 'kay', 'kuya', 'wil']
# Sentence after removing stopwords: ['vocalist', 'bandang', 'the', 'juans', 'itinanggi', 'bintang', 'pagsabi', 'b', 'b', 'bongbong']
# Sentence after removing stopwords: ['kontrabida', 'ngunit', 'mukhang', 'nakakatawa', 'nangyari', 'kay', 'joaquin', 'buwaya', 'fajardo']
# Sentence after removing stopwords: ['marian', 'rivera', 'naniniwala', 'kakayahan', 'jane', 'de', 'leon', 'darna']
# Sentence after removing stopwords: ['bukod', '10m', 'manny', 'pangilinan', 'handang', 'ibigay', 'hiling', 'hidilyn']
# Sentence after removing stopwords: ['math', 'teacher', 'piniling', 'ring', 'ipagpatuloy', 'pagtuturo', 'kabila', 'pagkawala', 'kanang', 'mata', 'tumor']
# Sentence after removing stopwords: ['marcelito', 'pomoy', 'nagbahagi', 'mensahe', 'namayapang', 'kaibigan', 'jovit', 'baldivino']
# Sentence after removing stopwords: ['ingat', 'ketchup', 'm0dus', 'laganap', 'pandemya']
# Sentence after removing stopwords: ['katapatan', 'dating', 'taxi', 'driver', 'binigyan', 'full', 'scholarship', 'australia', 'pasaherong', 'businessman']
# Sentence after removing stopwords: ['dating', 'sikat', 'dancer', 'kuya', 'wil', 'luningning', 'buhay']
# Sentence after removing stopwords: ['kahera', 'pilit', 'pinaaming', 'nagnakaw', 'pera', 'tanggal', 'trabaho', 'kinuha', 'sweldo']
# Sentence after removing stopwords: ['batang', 'camsur', 'pinuri', 'social', 'media', 'husay', 'guhit']
# Sentence after removing stopwords: ['gaano', 'kayaman', 'andrew', 'e', 'nakamit', 'king', 'of', 'tagalog', 'rap', 'muntik', 'siyang', 'makulong']
# Sentence after removing stopwords: ['nagpapanggap', 'delivery', 'boy', 'shopee', 'umubra', 'alistong', 'customer']
# Sentence after removing stopwords: ['binatang', 'nagtitinda', 'leche', 'flan', 'iniipon', 'kita', 'pampa', 'opera', 'pang', 'matrikula']
# Sentence after removing stopwords: ['aksyon', 'maraming', 'tao', 'lalo', 'kabataan', 'pagliligo', 'gabi', 'mataas', 'rate', 'stroke', 'biglang', 'pagbabago', 'presyon', 'dugo']
# Sentence after removing stopwords: ['jayda', 'anak', 'nina', 'jessa', 'dingdong', 'avanzado', 'sasabak', 'rin', 'arte']
# Sentence after removing stopwords: ['sikat', 'supermarket', 'ibinabawas', 'umano', 'naibentang', 'turon', 'sahod', 'empleyado']
# Sentence after removing stopwords: ['asawang', 'bulag', 'patuloy', 'lumalaban', 'itinataguyod', '8', 'anak']
# Sentence after removing stopwords: ['seller', 'nahulog', 'putikan', 'nagdeliver', 'naglabas', 'saloobin', 'nambabarat', 'free', 'delivery', 'fee']
# Sentence after removing stopwords: ['balik', 'tanaw', 'eat', 'bulaga', 'host', 'jose', 'manalo', 'boyoyong', 'clowns']
# Sentence after removing stopwords: ['pambansang', 'bangkay', 'jose', 'clemente', 'kahanga', 'hanga', 'pala', 'talento', 'pasukin', 'showbiz']
# Sentence after removing stopwords: ['proud', 'anak', 'iniaalay', 'pagtatapos', 'kolehiyo', 'inang', 'problema', 'iisip']
# Sentence after removing stopwords: ['kontrobersyal', 'celebrity', "'cheating'", 'breakups', 'naaalala', 'niyo', 'ba']
# Sentence after removing stopwords: ['zsa', 'zsa', 'padilla', 'ipinasilip', 'napakalawak', 'lupain', 'comedy', 'king', 'dolphy', 'dolphyville']
# Sentence after removing stopwords: ['ama', 'nahilo', 'nahimatay', 'paglalako', 'karga', 'anak']
# Sentence after removing stopwords: ['kapapasok', 'lang', 'sawakas', 'pres', 'marcos', 'kina', 'usap', 'nasi', 'soj', 'remulla', 'disisyon', 'tangal', 'nasa', 'pwesto']
# Sentence after removing stopwords: ['lalaking', 'putol', 'kalahating', 'katawan', 'hinangaan', 'netizens', 'pagiging', 'masipag', 'kabila', 'kalagayan']
# Sentence after removing stopwords: ['pinay', 'helper', 'malaysia', 'binigyan', '100k', 'gamit', 'pang', 'paayos', 'bahay', 'mabait', 'employer']
# Sentence after removing stopwords: ['sobrang', 'yaman', 'pala', 'michael', 'de', 'mesa', 'maswerte', 'asawa', '13', 'taon', 'edad']
# Sentence after removing stopwords: ['2', 'year', 'old', 'baby', 'iniwan', 'magulang', 'loob', 'sasakyan', 'iinuman']
# Sentence after removing stopwords: ['magnanakaw', 'tinanggihan', 'perang', 'ibinibigay', 'matanda', 'hinalikan', 'noo', 'upang', 'kumalma']
# Sentence after removing stopwords: ['garbage', 'collector', 'napagtapos', 'panganay', 'kolehiyo', 'aaral', 'architect', 'guro', 'highschool']
# Sentence after removing stopwords: ['prof', 'clarita', 'carlos', 'binigyan', 'assignment', 'anak', 'kiko', 'pangilinan', 'kakie']
# Sentence after removing stopwords: ['kwento', 'mister', 'matapos', 'nitong', 'bantayan', 'alagaan', 'anak', 'kinabiliban', 'misis', 'netizens']
# Sentence after removing stopwords: ['barangay', 'official', 'hinarang', 'grab', 'delivery', 'rider', 'daw', 'essential', 'lugaw']
# Sentence after removing stopwords: ['kapansanang', 'ama', 'matagal', 'pinag', 'iipunan', 'pambili', 'sapatos', 'anak']
# Sentence after removing stopwords: ['buhay', 'tinaguriang', 'reyna', 'horror', 'movies', 'lilia', 'cuntapay', 'pala', 'sinapit', 'aktres']
# Sentence after removing stopwords: ['construction', 'worker', 'rumarampa', 'a', 'la', 'catriona', 'gray', 'certified', 'pampa', 'good', 'vibes']
# Sentence after removing stopwords: ['32', 'anyos', 'bulag', 'pagkasilang', 'nakatanggap', 'ayuda', 'matapos', 'manawagan', 'tulong', 'kaniyang', 'tiyahin']
# Sentence after removing stopwords: ['matapos', 'makatanggap', "'goodie", "bag'", 'kapalit', '27', 'taon', 'absent', 'trabaho', 'empleyado', 'biniyayaan', '270k']
# Sentence after removing stopwords: ['maricar', 'reyes', 'nagsalita', 'past', 'scandal', '13', 'years', 'it', 'took', 'a', 'long', 'time', 'to', 'heal', 'and', 'process']
# Sentence after removing stopwords: ['basurera', 'ceo', 'business']
# Sentence after removing stopwords: ['busy', 'wifey', 'mister', 'kakaibang', 'pakulo', 'lang', 'makasama', 'misis', 'bakasyon']
# Sentence after removing stopwords: ['ipinagmamalaking', 'tatay', 'lalaking', 'lasing', 'nagwawala', 'viral', 'video', 'nakilala', 'n', 'yo', 'ba', 'kilala', 'tatay']
# Sentence after removing stopwords: ['asawang', 'nanirahan', 'kulungan', 'baboy', 'nagtulungan', 'nagsikap', 'magkaroon', 'sariling', 'bahay']
# Sentence after removing stopwords: ['pamilya', 'nagpakulong', '84', 'anyos', 'lolo', 'nagsalita', 'sana', 'raw', 'humingi', 'sorry', 'lolo']
# Sentence after removing stopwords: ['netizens', 'nakakaamoy', 'hiwalayan', 'sunshine', 'cruz', 'macky', 'mathay', 'break', 'daw', 'matapos', 'nakakaintrigang', 'post', 'aktres']
# Sentence after removing stopwords: ['nga', 'ba', 'jose', 'mari', 'chan', 'kumakanta', 'christmas', 'in', 'our', 'hearts']
# Sentence after removing stopwords: ['negosyante', 'sasagutin', 'kakailanganing', 'tulong', 'kaso', 'lolo', 'narding']
# Sentence after removing stopwords: ['estudyanteng', 'kapansanan', 'pinagsasabay', 'paglalako', 'itlog', 'chicharon', 'upang', 'matustusan', 'aaral']
# Sentence after removing stopwords: ['remembering', 'marky', 'cielo', 'proud', 'igorot', 'and', 'starstruck', 'ultimate', 'male', 'survivor']
# Sentence after removing stopwords: ['netizen', 'inilabas', 'sekretong', 'galit', 'lang', 'my', 'day', 'kakilala', 'tameme', 'niresbakan']
# Sentence after removing stopwords: ['pinoy', 'vlogger', 'tumulong', 'kay', 'nas', 'daily', 'nagsalita', 'parang', 'ginamit', 'lang', 'naabuso', 'sya', 'kilala']
# Sentence after removing stopwords: ['grabe', 'unang', 'gabi', 'lamay', 'burol', 'kris', 'aquino', 'dinagsa', 'tao', 'kaibigan', 'kamag', 'anak']
# Sentence after removing stopwords: ['tattoo', 'artist', 'walong', 'asawa', 'magkakasamang', 'naninirahan', 'iisang', 'bubong']

# %%
df['trigrams'] = df['cleaned'].apply(lambda x: generate_N_grams(x,3))
# Out:
# Sentence after removing stopwords: ['lalaki', 'patay', 'pamamaril', 'tondo', 'maynila']
# Sentence after removing stopwords: ['50', 'pinoy', 'naipit', 'kaguluhan', 'sudan', 'nailikas']
# Sentence after removing stopwords: ['boyingresign', 'netizens', 'galit', 'kay', 'doj', 'chief', 'remulla', 'matapos', 'mahulihan', 'high', 'grade', 'marijuana', 'anak']
# Sentence after removing stopwords: ['backdoor', 'entry', 'grab', 'motorcycle', 'taxi', 'pilot', 'pinaiimbestigahan']
# Sentence after removing stopwords: ['doktor', 'nangangamba', 'mild', 'stroke', 'de']
# Sentence after removing stopwords: ['japan', 'coast', 'guard', 'nagpasalamat', 'pcg', 'pagsagip', 'japanese', 'crew', 'nakaranas', 'maritime', 'accident']
# Sentence after removing stopwords: ['employment', 'rate', 'umangat', 'noong', 'pebrero']
# Sentence after removing stopwords: ["'amang'", 'landfall', 'lagonoy', 'camarines', 'sur', '11', 'lugar', 'nasa', 'signal', 'no', '1']
# Sentence after removing stopwords: ['robinhood', 'padilla', 'gawing', 'legal', 'paggamit', 'medical', 'marijuana']
# Sentence after removing stopwords: ['pangulong', 'duterte', 'sinisisi', 'kakulangan', 'covid', '19', 'vaccines']
# Sentence after removing stopwords: ['isabela', 'lgu', 'posibleng', 'natagpuan', 'bahagi', 'nawawalang', 'cessna', 'plane']
# Sentence after removing stopwords: ['9', 'tips', 'makatipid', 'tubig', 'tag', 'init']
# Sentence after removing stopwords: ['bagyong', 'obet', 'posible', 'pang', 'lumakas', 'signal', 'no', '1', 'nakataas', 'bahagi', 'northern', 'luzon']
# Sentence after removing stopwords: ['download', 'speed', 'fixed', 'broadband', 'internet', 'bansa', 'muling', 'tumaas']
# Sentence after removing stopwords: ['580', 'preso', 'sabay', 'sabay', 'pinalaya', "'good", "behavior'"]
# Sentence after removing stopwords: ['bitay', 'sangkot', 'ilegal', 'droga', 'itutulak', 'rep', 'barbers']
# Sentence after removing stopwords: ['pagiging', 'no', '3', 'robin', 'padilla', 'survey', 'ipinagtanggol', 'ipatupad', 'partylist', 'natin', 'siyang', 'husgahan']
# Sentence after removing stopwords: ['jeepney', 'group', 'nanawagan', 'ltfrb', 'palawigin', 'deadline', 'implementasyon', 'jeepney', 'modernization', 'program']
# Sentence after removing stopwords: ['lanao', 'del', 'sur', 'gov', 'adiong', 'sugatan', 'ambush', '4', 'kasamahan', 'patay']
# Sentence after removing stopwords: ['pasahe', 'lrt', 'nagbabadyang', 'tumaas', 'matapos', 'aprubahan', 'ltfrb']
# Sentence after removing stopwords: ['dict', 'deadline', 'sim', 'registration', 'abril', '26', 'rin']
# Sentence after removing stopwords: ['anak', 'nina', 'luis', 'manzano', 'jessy', 'mendiola', 'baby', 'peanut', 'bininyagan', 'alex', 'gonzaga', 'nikki', 'gil', 'tumayong', 'ninang']
# Sentence after removing stopwords: ['pnp', 'magde', 'deploy', 'mas', 'maraming', 'pulis', 'ngayong', 'kapaskuhan']
# Sentence after removing stopwords: ['teves', 'humingi', 'tulong', 'kay', 'pbbm', 'umano', 'y', 'panggigipit', 'ilang', 'opisyal']
# Sentence after removing stopwords: ['dswd', 'up', 'tutulong', 'habulin', 'child', 'support', 'magulang', 'ibang', 'bansa']
# Sentence after removing stopwords: ['ilang', 'lugar', 'visayas', 'mindanao', 'positibo', 'red', 'tide', 'bfar']
# Sentence after removing stopwords: ['anak', 'doj', 'chief', 'remulla', 'not', 'guilty', 'kasong', 'illegal', 'drug', 'possession']
# Sentence after removing stopwords: ['ngo', 'nababahala', 'pagkalat', 'covid', '19', 'inililikas', 'aalburutong', 'bulkang', 'taal']
# Sentence after removing stopwords: ['dating', 'japanese', 'pm', 'shinzo', 'abe', 'pumanaw', 'matapos', 'barilin']
# Sentence after removing stopwords: ['romualdez', 'dismayado', 'pagkadawit', 'ilang', 'pnp', 'officials', 'p6', '7', 'billion', 'shabu']
# Sentence after removing stopwords: ['higit', '300', 'manlalaro', 'lumahok', 'finals', 'rodeo', 'masbate']
# Sentence after removing stopwords: ['bong', 'go', 'china', 'taiwan', 'tension', 'ofws', 'tiyaking', 'ligtas']
# Sentence after removing stopwords: ['giant', 'billboard', 'imelda', 'marcos', 'trending', 'social', 'media']
# Sentence after removing stopwords: ['grupo', 'nanawagan', 'deped', 'chedna', 'tugunan', 'tinwag', 'vape', 'epidemic', 'kabataang', 'pilipino']
# Sentence after removing stopwords: ['support', 'group', 'mapalaya', 'pinakamatandang', 'bilanggong', 'pulitikal']
# Sentence after removing stopwords: ['oriental', 'mindoro', 'makaranas', 'blackout']
# Sentence after removing stopwords: ['pilipinong', 'kabilang', 'namatay', 'banggaan', '2', 'tren', 'greece']
# Sentence after removing stopwords: ['kampo', 'cong', 'teves', 'ki', 'nuwestyong', 'narekober', 'granada', 'kaniyang', 'tahanan']
# Sentence after removing stopwords: ['new', 'year', 'message', 'pbbm', 'filipino', 'chinese', 'have', 'deeper', 'compassion', 'to', 'those', 'who', 'have', 'less', 'in', 'life']
# Sentence after removing stopwords: ['p4', '7', 'b', 'halaga', 'service', 'contracting', 'payouts', 'naibigay', 'driver', 'operator']
# Sentence after removing stopwords: ['opisyal', 'barangay', 'san', 'jose', 'del', 'monte', 'sorry', 'grab', 'rider', 'kaugnay', 'kontrobersiya', 'lugaw']
# Sentence after removing stopwords: ['mambabatas', 'naghain', 'resolusyon', 'upang', 'imbestigahan', 'kuwestyonableng', 'third', 'party', 'auditor', 'pagcor']
# Sentence after removing stopwords: ['globe', 'planthappinessph', 'mental', 'health', 'campaign', 'umani', 'higit', '168', '7', 'milyong', 'views', 'tiktok']
# Sentence after removing stopwords: ['kakulangan', 'imprastraktura', 'resources', 'nakikitang', 'most', 'pressing', 'issue', 'kinakaharap', 'sektor', 'edukasyon', 'bansa']
# Sentence after removing stopwords: ['qc', 'traffic', 'enforcer', 'nakapagsagip', 'siklista', 'masagasaan', 'mamatay']
# Sentence after removing stopwords: ['panukala', 'magbabawal', 'substitution', 'of', 'candidacy', 'inihain', 'kamara']
# Sentence after removing stopwords: ['pangulong', 'marcos', 'pabahay', 'kada', 'taon', 'lalampas', '1', 'milyon']
# Sentence after removing stopwords: ['pagsusuot', 'face', 'shield', 'kinakailangan', 'maynila', 'maliban', 'medical', 'facilities']
# Sentence after removing stopwords: ['popcom', 'naaalarma', 'teen', 'pregnancy', 'pinakabata', 'nasa', 'edad', '10']
# Sentence after removing stopwords: ['2', 'batang', 'magkapatid', 'patay', 'sunog', 'mandaluyong']
# Sentence after removing stopwords: ['signal', 'no', '1', 'nakataas', 'rin', 'bahagi', 'luzon', 'classes', 'suspension', 'idineklara', 'ilang', 'probinsya']
# Sentence after removing stopwords: ['balikatan', 'exercises', '2023', 'all', 'set']
# Sentence after removing stopwords: ['ppa', 'libreng', 'pagkain', 'mai', 'stranded', 'pasahero', 'pantalan']
# Sentence after removing stopwords: ['partial', 'solar', 'eclipse', 'nasilayan', 'ibang', 'lugar', 'ph']
# Sentence after removing stopwords: ['rider', 'nangholdap', 'cake', 'shop', 'quezon', 'city']
# Sentence after removing stopwords: ['manny', 'villar', 'nangunguna', 'richest', 'filipinos', 'forbes', 'magazine']
# Sentence after removing stopwords: ['dumalo', 'uniteam', 'rally', 'nawalan', 'cellphone', 'wallet', 'parang', 'awa', 'n', 'yo', 'po', 'pakisauli', 'lang', 'po']
# Sentence after removing stopwords: ['mahihirap', 'bacolod', 'city', 'tinulungan', 'bong', 'go']
# Sentence after removing stopwords: ['apela', 'newsnet', 'ibinasura', 'palasyo']
# Sentence after removing stopwords: ['pnp', 'cidg', 'binasura', 'pagkakasangkot', 'police', 'escorts', 'gov', 'degamo', 'pagpatay']
# Sentence after removing stopwords: ['mmda', 'number', 'coding', 'scheme', 'suspendido', 'april', '6', '10']
# Sentence after removing stopwords: ['p128', 'milyong', 'pondo', 'nakalaan', 'biktima', 'tropical', 'storm', 'maring']
# Sentence after removing stopwords: ['panukalang', 'naglalayong', 'suspendihin', 'mother', 'tongue', 'medium', 'pagtuturo', 'bata', 'lusot', 'ikalawang', 'pagbasa', 'kamara']
# Sentence after removing stopwords: ['mahigit', 'p6', '8m', 'halaga', "'shabu'", 'nasabat', 'buy', 'bust', 'operation', 'taguig']
# Sentence after removing stopwords: ['takot', 'filipino', 'covid', '19', 'record', 'high', 'sws', 'survey']
# Sentence after removing stopwords: ['dotr', 'maghihigpit', 'seguridad', 'mrt', '3', 'matapos', 'tumalon', 'pasahero']
# Sentence after removing stopwords: ['barbie', 'forteza', 'pinapili', 'love', 'career', 'netizens', 'bumilib', 'sagot']
# Sentence after removing stopwords: ['hirit', 'transport', 'group', 'p3', 'dagdag', 'pasahe', 'pinalagan']
# Sentence after removing stopwords: ['oldest', 'pinoy', 'lola', 'francisca', 'susano', 'pumanaw', 'edad', '124']
# Sentence after removing stopwords: ['gobyerno', 'wala', 'gagawing', 'aksyon', 'matapos', 'ibasura', 'icc', 'apela', 'bansa', 'suspendihin', 'imbestigasyon', 'drug', 'war']
# Sentence after removing stopwords: ['ika', 'mananaya', 'nanalo', 'jackpot', 'lotto', 'loob', 'linggo']
# Sentence after removing stopwords: ['kaso', 'covid', '19', 'pilipinas', 'sumampa', 'higit', '784', '000']
# Sentence after removing stopwords: ['kampo', 'pinaslang', 'ex', 'mayor', 'ateneo', 'campus', 'umalma', 'isyu', 'ilegal', 'droga', 'that', 'is', 'not', 'true']
# Sentence after removing stopwords: ['fda', '18', 'bata', 'nakaranas', 'side', 'effect', 'sangobion', 'kids', 'syrup']
# Sentence after removing stopwords: ['mexican', 'beauty', 'queen', 'kaniyang', 'partner', 'kulong', 'pagsikwat', 'alak', 'spain']
# Sentence after removing stopwords: ['sotto', 'hinikayat', 'gobyerno', 'magpatupad', 'price', 'freeze', 'lugar', 'apektado', 'bagyong', 'odette']
# Sentence after removing stopwords: ['bwelta', 'bongbong', 'bashers', 'duwag', 'tao', 'wala', 'akong', 'iniiwasan']
# Sentence after removing stopwords: ['dahilan', 'paglihis', 'tren', "'di", 'tukoy', 'pnr']
# Sentence after removing stopwords: ['asawa', '3', 'anak', 'patay', 'sunog', 'natagpuan', 'rumespondeng', 'fire', 'marshall', 'magkakayakap']
# Sentence after removing stopwords: ['infinite', 'radio', 'calbayog', 'nagdiwang', 'ikalawang', 'anibersaryo']
# Sentence after removing stopwords: ['senador', 'paimbestigahan', 'operasyon', 'pcso', 'katanungan', 'lehitimong', 'nananalo', 'lotto', 'grand', 'prize']
# Sentence after removing stopwords: ['provisional', 'toll', 'rates', 'skyway', 'stage', '3', 'aprubado']
# Sentence after removing stopwords: ['lalaki', 'huli', 'pangmomolestiya', 'menor', 'de', 'edad', 'qc']
# Sentence after removing stopwords: ['13', '000', 'mt', 'imported', 'galunggong', 'dumating', 'bansa']
# Sentence after removing stopwords: ['pba', 'mapait', 'game', '4', 'loss', 'kay', 'standhardinger']
# Sentence after removing stopwords: ['doe', 'tiniyak', 'red', 'yellow', 'alert', 'malampaya', 'maintenance']
# Sentence after removing stopwords: ['panel', 'review', 'result', 'pnp', 'officials', 're', 'illegal', 'drug', 'trade', 'matatapos', 'loob', '2', 'linggo']
# Sentence after removing stopwords: ['suspensiyon', 'trump', 'facebook', 'tatagal', '2023']
# Sentence after removing stopwords: ['posts', 'navigation']
# Sentence after removing stopwords: ['pagpapatuloy', 'allowance', 'healthworkers', 'ipinag', 'utos', 'pangulo']
# Sentence after removing stopwords: ['teves', 'dadalo', 'senate', 'probe', 'degamo', 'slay']
# Sentence after removing stopwords: ['pcso', 'umaasa', 'malaking', 'kita', 'sweepstakes', 'malnutrisyon', 'lalabanan']
# Sentence after removing stopwords: ['biyahe', 'pnr', 'maynila', 'naantala', 'kotseng', 'bumalandra', 'riles']
# Sentence after removing stopwords: ['senador', 'humiling', 'congressional', 'inquiry', 'status', 'pagpapatupad', 'anti', 'bullying', 'act']
# Sentence after removing stopwords: ['look', 'lugar', 'nakasailalim', 'lockdown', 'qc']
# Sentence after removing stopwords: ['karagdagang', 'alokasyon', 'tubig', 'mwss', 'kakayanin', 'nwrb']
# Sentence after removing stopwords: ['p1', '6b', 'inilaan', 'rehabilitasyon', 'manila', 'bay']
# Sentence after removing stopwords: ['vico', 'sotto', 'apektado', 'cyberlibel', 'case', 'isinampa', 'bernardo', 'it', 's', 'nothing', 'personal']
# Sentence after removing stopwords: ['knows', 'n', 'yo', 'ba', 'maiiwasan', 'heatstroke', 'lalo', 'ngayong', 'tag', 'init']
# Sentence after removing stopwords: ['juan', 'ponce', 'enrile', 'tinamaan', 'covid', '19', 'i', 'm', 'not', 'gonna', 'die', 'yet']
# Sentence after removing stopwords: ['mundo', 'teves', 'paliliitin', 'ituturing', 'terorista', 'doj']
# Sentence after removing stopwords: ['lto', 'pinaigting', 'kampanya', 'overloading', 'vehicles']
# Sentence after removing stopwords: ['101', 'itinaas', 'kaso', 'typhoid', 'doh']
# Sentence after removing stopwords: ['kilalanin', 'top', '30', 'bar', 'passers', 'taong', '2022']
# Sentence after removing stopwords: ['marcos', 'bumuo', 'inter', 'agency', 'committtee', 'tututok', 'inflation']
# Sentence after removing stopwords: ['teves', 'kinatatakutan', 'umanong', 'pamilya', 'negros', 'oriental']
# Sentence after removing stopwords: ['paggamit', 'face', 'shield', 'pinag', 'aaralang', 'ibalik', 'harap', 'banta', 'omicron']
# Sentence after removing stopwords: ['ilang', 'lugar', 'maynila', 'magpapatupad', 'liquor', 'ban']
# Sentence after removing stopwords: ['presyo', 'petrolyo', "'dagdag", "bawas'", 'abril', '18']
# Sentence after removing stopwords: ['nanay', 'pasig', 'pinatay', 'kaniya', 'umanong', 'sariling', 'anak']
# Sentence after removing stopwords: ['3', 'patay', 'salpukan', 'motor', 'kotse', 'batangas']
# Sentence after removing stopwords: ['remulla', 'mensahe', 'kay', 'teves', 'jr', 'ngayong', 'semana', 'santa']
# Sentence after removing stopwords: ['kongreso', 'tinaasan', 'cancer', 'funds', 'pilipino', 'p1', '56b']
# Sentence after removing stopwords: ['2', 'lalaki', 'huli', 'ilegal', 'umanong', 'pagbebenta', 'e', 'cigarettes', 'vape', 'products']
# Sentence after removing stopwords: ['20', 'probinsiya', 'lang', 'di', 'napapasok', 'asf']
# Sentence after removing stopwords: ['brigada', 'news', 'philippines']
# Sentence after removing stopwords: ['bulkang', 'mayon', 'nagtala', 'pagyanig', 'nakataas', 'rin', 'alert', 'level', '2']
# Sentence after removing stopwords: ['bong', 'go', 'linggo', 'pagkabuhay', 'wag', 'mawalan', 'asa', 'tiwala']
# Sentence after removing stopwords: ['hugis', 'pusong', 'clearing', 'woodland', 'farmer', 'namayapang', 'asawa']
# Sentence after removing stopwords: ['covid', '19', 'aakyat', '600', 'kada', 'araw', 'mayo', 'doh']
# Sentence after removing stopwords: ['pagsugpo', 'pang', 'aabuso', 'paaralan', 'pinaigting', 'deped', 'naglunsad', 'helpline']
# Sentence after removing stopwords: ['dayuhang', 'nagmamaltrato', 'asawang', 'pinay', 'cebu', 'arestado']
# Sentence after removing stopwords: ['marcos', 'inaasahang', 'magsasagawa', 'state', 'visit', 'france']
# Sentence after removing stopwords: ['teves', 'camp', 'umaasang', 'magiging', 'witch', 'hunt', 'senate', 'hearing', 'degamo', 'slay', 'case']
# Sentence after removing stopwords: ['mrt', '3', 'libreng', 'sakay', 'beterano', 'april', '10', 'to', '12']
# Sentence after removing stopwords: ['senador', 'nanawagan', 'philhealth', 'bigyan', 'kaunting', 'kaluwagan', 'ofws', 'pagbabayad', 'premium', 'contributions']
# Sentence after removing stopwords: ['vp', 'leni', 'robredo', 'kakandidatong', 'pangulo', 'bansa', 'buong', 'buo', 'loob']
# Sentence after removing stopwords: ['marcos', 'kailangang', 'import', 'produkto', 'sakaling', 'malakas', 'msmes']
# Sentence after removing stopwords: ['vg', 'jolo', 'revilla', 'prayoridad', 'sahod', 'manggagawang', 'cavite']
# Sentence after removing stopwords: ['ex', 'dfa', 'sec', 'albert', 'del', 'rosario', 'pumanaw']
# Sentence after removing stopwords: ['ayuda', 'dswd', 'suspendido', 'muna', 'ngayong', 'holy', 'week']
# Sentence after removing stopwords: ['grab', 'nangako', 'kay', 'pangulong', 'marcos', 'kalahating', 'milyong', 'trabaho', 'pilipino']
# Sentence after removing stopwords: ['lutong', 'pinoy', 'gustong', 'ipakilala', 'loren', 'legarda', 'buong', 'mundo']
# Sentence after removing stopwords: ['bi', 'inaasahang', 'papalo', '50k', 'arrivals', 'holy', 'week']
# Sentence after removing stopwords: ['barker', 'quezon', 'city', 'binaril', 'taxi', 'driver', 'daw', 'p5']
# Sentence after removing stopwords: ['remote', 'work', 'facebook', 'forever']
# Sentence after removing stopwords: ['doh', 'nakapagtala', 'halos', '1', '500', 'kaso', 'hiv', 'noong', 'enero']
# Sentence after removing stopwords: ['ina', 'dr', 'chao', 'tiao', 'yumol', 'nanawagan', 'kay', 'bongbong', 'marcos', 'nasa', 'panganib']
# Sentence after removing stopwords: ['5', '3', 'lindol', 'yumanig', 'ilang', 'bahagi', 'luzon']
# Sentence after removing stopwords: ['dating', 'pulis', 'sangkot', 'pagpatay', '2', 'teenager', 'hinatulan', 'korte', '40', 'taong', 'pagkakakulong']
# Sentence after removing stopwords: ['obispo', 'batanes', 'humihingi', 'tulong', 'nabiktima', 'bagyong', 'kiko']
# Sentence after removing stopwords: ['sky', 'lantern', 'thailand', 'bumagsak', 'sumabog']
# Sentence after removing stopwords: ['higit', '100', 'property', 'developers', 't', 'uuml', 'rkiye', 'inaresto', 'kaugnay', 'pagguho', 'gusali', 'lindol']
# Sentence after removing stopwords: ['globe', 'libreng', 'tawag', 'charging', 'wifi', 'nakahanda', 'apektado', 'dante']
# Sentence after removing stopwords: ["umano'y", 'illegal', 'recruiter', 'nangako', 'trabaho', 'canada', 'timbog']
# Sentence after removing stopwords: ['vp', 'leni', 'natuwa', 'pagbisita', 'tarlac', 'pnoy', 'be', 'gone', 'now', 'but', 'josh', 'being', 'there', 'really', 'meant', 'a', 'lot']
# Sentence after removing stopwords: ['food', 'and', 'waterborne', 'disease', 'bansa', 'tumaas']
# Sentence after removing stopwords: ['7', 'araw', 'sim', 'registration', 'deadline', 'pagpaparehistro', 'rin', 'extended']
# Sentence after removing stopwords: ['veteran', 'broadcaster', 'dong', 'puno', 'pumanaw', 'edad', '76']
# Sentence after removing stopwords: ['ex', 'gov', 'teves', 'naghain', 'waiver', 'doj', 'nagpapahintulot', 'tingnan', 'phone', 'bank', 'accounts']
# Sentence after removing stopwords: ['pang', 'lugar', 'muntinlupa', 'naka', 'lockdown', 'rin']
# Sentence after removing stopwords: ['self', 'confessed', 'gunman', 'percy', 'lapid', 'slay', 'case', 'joel', 'escoria', 'nailipat', 'pnp', 'custodial', 'center']
# Sentence after removing stopwords: ['senador', 'zubiri', 'raw', 'maintindihan', 'madaliin', 'kamara', 'cha', 'cha']
# Sentence after removing stopwords: ['who', 'nababahala', 'secondary', 'health', 'crisis', 'turkey', 'kasunod', 'magnitude', '7', '8', 'lindol']
# Sentence after removing stopwords: ['asia', 's', 'superstar', 'kathryn', 'bernardo', 'tnt', 'tropa']
# Sentence after removing stopwords: ['dating', 'desk', 'officer', 'pnp', 'bayawan', 'negros', 'oriental', 'pina', 'cite', 'in', 'contempt', 'senado']
# Sentence after removing stopwords: ['pnp', 'blanko', 'kinaroroonan', 'drug', 'lord', 'peter', 'lim']
# Sentence after removing stopwords: ['pinabulaanang', 'tinurture', 'muna', 'asawang', 'tiamzon', 'patayin']
# Sentence after removing stopwords: ['bi', 'iniimbestigahan', 'iniulat', 'illegal', 'scamming', 'hubs']
# Sentence after removing stopwords: ['pagbabayad', 'buwis', 'caloocan', 'city', 'online', 'rin']
# Sentence after removing stopwords: ['ex', 'dfa', 'chief', 'albert', 'del', 'rosario', 'pumanaw', 'edad', '83']
# Sentence after removing stopwords: ['suicide', 'cases', 'tumaas', 'noong', '2020', 'suporta', 'estudyante', 'hiniling', 'sen', 'gatchalian']
# Sentence after removing stopwords: ['8', 'arestado', 'bulacan', 'gumagawa', 'umano', 'ilegal', 'paputok']
# Sentence after removing stopwords: ['rehistradong', 'sim', 'cards', 'nasa', '133', '6m', 'rin']
# Sentence after removing stopwords: ['lalaking', 'nagnakaw', 'umano', 'bike', 'shop', 'arestado', 'qc']
# Sentence after removing stopwords: ['dalai', 'lama', 'humingi', 'paumanhin', 'pahalikin', 'batang', 'lalaki', 'kaniyang', 'dila']
# Sentence after removing stopwords: ['manilenyo', 'wagi', 'p16m', 'jackpot', 'prize', 'lotto']
# Sentence after removing stopwords: ['house', 'donate', 'karagdagang', 'p10m', 'humanitarian', 'aid', 'biktima', 'lindol', 'turkey']
# Sentence after removing stopwords: ['tulfo', 'hinimok', 'pcso', 'bigyan', 'health', 'benefits', 'small', 'time', 'bet', 'collectors']
# Sentence after removing stopwords: ['bong', 'go', 'umatras', 'pagtakbong', 'pangulo']
# Sentence after removing stopwords: ['di', 'kamag', 'anak', 'teves', 'sen', 'bato']
# Sentence after removing stopwords: ['9', 'sugatan', 'tumagilid', 'jeep', 'kamuning']
# Sentence after removing stopwords: ['ping', 'lacson', 'bongbong', 'marcos', 'leody', 'nakaboto', 'kani', 'voting', 'precinct']
# Sentence after removing stopwords: ['dengue', 'tag', 'init', 'babala', 'doh']
# Sentence after removing stopwords: ['suspek', 'pagpatay', 'dayuhang', 'taga', 'new', 'zealand', 'sumuko']
# Sentence after removing stopwords: ['kamara', 'inaprubahan', '2nd', 'reading', 'accompanying', 'bill', 'rbh', 'no', '6', 'nagpapatawag', 'con', 'con']
# Sentence after removing stopwords: ['pinatutumba', 'umano', 'teves', 'akusadong', 'pulis', 'nagkaharap']
# Sentence after removing stopwords: ['6', 'empleyado', 'teves', 'naabutan', 'raid', 'properties', 'nasa', 'kustodiya', 'pnp', 'cidg']
# Sentence after removing stopwords: ['cannahopefuls', 'isinusulong', 'gawing', 'legal', 'medical', 'marijuana']
# Sentence after removing stopwords: ['filipina', 'trafficking', 'victim', 'myanmar', 'nagbayad', 'ransom', 'bi']
# Sentence after removing stopwords: ['ufc', 'middleweight', 'world', 'title', 'nabawi', 'adesanya']
# Sentence after removing stopwords: ['mindore', 'nasungkit', 'p378m', 'ultralotto', '6', '58', 'jackpot']
# Sentence after removing stopwords: ['suspek', 'salilig', 'hazing', 'case', 'sumuko', '6', 'sinampahan', 'reklamo']
# Sentence after removing stopwords: ['lalaking', 'wanted', 'pananaksak', 'live', 'in', 'partner', 'zamboanga', 'sibugay', 'arestado', 'qc']
# Sentence after removing stopwords: ['comelec', 'susubaybayan', 'pagsunod', 'campaign', 'rules', '4', 'kandidato', 'special', 'election', 'cavite', '7th', 'district']
# Sentence after removing stopwords: ['4', 'sugatan', 'matapos', 'bumagsak', 'wawa', 'bridge', 'pangasinan']
# Sentence after removing stopwords: ['lalaking', 'amok', 'patay', 'pananaksak', 'tondo']
# Sentence after removing stopwords: ['bwelta', 'jv', 'ejercito', 'chikang', 'nakabuntis', 'wag', 'kayong', 'istorya', 'asawa', 'po', 'tao']
# Sentence after removing stopwords: ['48', 'patay', '40', 'sugatan', 'pananalasa', 'bagyong', 'paeng', '22', 'katao', 'nawawala']
# Sentence after removing stopwords: ['testing', 'quarantine', 'protocols', 'pilipinong', 'galing', 'ibang', 'bansa', 'niluwagan']
# Sentence after removing stopwords: ['who', 'di', 'tiyak', 'aalisin', 'covid', '19', 'public', 'health', 'emergency']
# Sentence after removing stopwords: ['twitter', 'pinalitan', 'logo', 'gaya', 'cryptocurrency', 'dogecoin']
# Sentence after removing stopwords: ['angkat', '330', '000', 'mt', 'bigas', 'iligal', 'ex', 'da', 'chief']
# Sentence after removing stopwords: ['covid', '19', 'kasama', 'top', '10', 'dahilan', 'pagkamatay', 'pilipinas']
# Sentence after removing stopwords: ['senador', 'lumagda', 'resolusyon', 'mariing', 'kumukondena', 'pagpaslang', 'kay', 'gov', 'degama']
# Sentence after removing stopwords: ['aeta', 'chieftain', 'missing', 'boracay', 'natagpuan']
# Sentence after removing stopwords: ['el', 'task', 'force', 'binuhay', 'da']
# Sentence after removing stopwords: ['babae', 'patay', 'matapos', 'umanong', 'saksakin', 'live', 'in', 'partner', 'caloocan', 'suspek', 'patay']
# Sentence after removing stopwords: ['babaeng', 'japanese', 'fugitive', 'arestado', 'opisina', 'bi', 'matapos', 'tangkaing', 'palawigin', 'tourist', 'visa']
# Sentence after removing stopwords: ['pagasa', 'lpa', 'asahang', 'papasok', 'bansa', 'magdadala', 'ulan']
# Sentence after removing stopwords: ['doh', 'hemophilia', 'lumapit', 'health', 'centers']
# Sentence after removing stopwords: ['marcos', 'nangakong', 'poprotektahan', 'kapakanan', 'ofws']
# Sentence after removing stopwords: ['hugot', 'isko', 'opo', 'lumaki', 'akong', 'busabos', 'ngunit', 'bastos']
# Sentence after removing stopwords: ['senate', 'probe', 'degamo', 'slay', 'di', 'magiging', 'kangaroo', 'court']
# Sentence after removing stopwords: ['marcos', 'tiwala', 'maaabot', 'bansa', 'rice', 'self', 'sufficiency', 'status', 'loob', 'dalawang', 'taon']
# Sentence after removing stopwords: ['rep', 'teves', 'humiling', 'makausap', 'pangulong', 'marcos']
# Sentence after removing stopwords: ['pagpapapako', 'krus', 'papayagan', 'san', 'fernando', 'pampanga', 'holy', 'week', '2023']
# Sentence after removing stopwords: ['dfa', 'handang', 'harapin', 'imbestigasyon', 'icc', 'war', 'on', 'drugs']
# Sentence after removing stopwords: ['alamin', 'myths', 'vs', 'facts', 'pagtutuli']
# Sentence after removing stopwords: ['nambugbog', '65', 'anyos', 'fil', 'new', 'york', 'city', 'nahuli']
# Sentence after removing stopwords: ['5', 'hinihinalang', 'drug', 'suspect', 'bicol', 'arestado', 'mahigit', 'p200k', 'halaga', 'shabu', 'nasabat']
# Sentence after removing stopwords: ['senador', 'isinusulong', 'pogo', 'zone']
# Sentence after removing stopwords: ['dfa', 'kinumpirmang', 'magpapadala', 'pilipinas', 'rescue', 'team', 'quake', 'hit', 'syria']
# Sentence after removing stopwords: ['suplay', 'bigas', 'sapat', 'di', 'import', 'da']
# Sentence after removing stopwords: ['marco', 'gumabao', 'ibinandera', 'relasyon', 'cristine', 'reyes', 'you', 'are', 'my', 'home', 'and', 'my', 'adventure', 'all', 'once']
# Sentence after removing stopwords: ['palasyo', 'tiniyak', 'handa', 'gobyerno', 'planong', 'transport', 'strike', 'lunes']
# Sentence after removing stopwords: ['pangulong', 'marcos', 'chinese', 'foreign', 'minister', 'qin', 'gang', 'nagkausap']
# Sentence after removing stopwords: ['97', 'lugar', 'bansa', 'nasa', 'alert', 'level', '4', 'doh']
# Sentence after removing stopwords: ['publiko', 'pinaalalahanang', 'sumunod', '5s', 'strategy', 'vs', 'dengue']
# Sentence after removing stopwords: ['cover', 'up', 'p6', '7', 'bilyong', 'shabu', 'haul', 'azurin']
# Sentence after removing stopwords: ['p85', 'srp', 'asukal', 'itatakda', 'da']
# Sentence after removing stopwords: ['bantag', 'dating', 'deputy', 'ricardo', 'zulueta', 'itinuturing', 'pugante', 'pnp']
# Sentence after removing stopwords: ['depositors', 'nawalan', 'pera', 'bank', 'hacking', 'hinikayat', 'magreklamo', 'bsp']
# Sentence after removing stopwords: ['pcg', 'haharangin', 'badjao', 'passenger', 'background', 'check', 'ipatutupad']
# Sentence after removing stopwords: ['dagdag', 'singil', 'meralco', 'generation', 'charge', 'uutay', 'utayin']
# Sentence after removing stopwords: ['ex', 'pdeg', 'chief', '48', 'kakasuhan', 'p6', '7', 'bilyong', 'shabu', 'cover', 'up']
# Sentence after removing stopwords: ["'tausug", "blend'", 'tea', 'layong', 'ipakilala', 'tausug']
# Sentence after removing stopwords: ['24', 'kolehiyo', 'unibersidad', 'pinayagan', 'magsagawa', 'limited', 'face', 'to', 'face', 'classes']
# Sentence after removing stopwords: ['libreng', 'sakay', 'meryenda', 'handog', 'tnt', 'lrt', '1', 'passengers', 'ika', '12', 'setyembre']
# Sentence after removing stopwords: ['teves', 'kinu', 'konsidera', 'umanong', 'posibleng', 'mastermind', 'pagpatay', 'kay', 'gov', 'degamo']
# Sentence after removing stopwords: ['47', 'opisyal', 'tauhan', 'pnp', 'mananagot', 'p6', '7', 'bilyong', 'shabu']
# Sentence after removing stopwords: ['pbbm', 'tiniyak', 'buong', 'suporta', 'atletang', 'sasabak', 'sea', 'games']
# Sentence after removing stopwords: ['solong', 'anak', 'nasawi', 'rin', 'umano', 'hazing', 'tau', 'gamma', 'phi', 'cebu']
# Sentence after removing stopwords: ['camarines', 'sur', 'polytechnic', 'colleges', 'naglabas', 'pahayag', 'ukol', 'plagiarized', 'speech', 'issue', 'magna', 'cum', 'laude', 'graduate']
# Sentence after removing stopwords: ['langis', 'lumubog', 'tanker', 'posibleng', 'tumatagas', 'rin']
# Sentence after removing stopwords: ['gang', 'india', 'pinaghahanap', 'matapos', 'nakawin', 'toneladang', 'dyebs', 'baka']
# Sentence after removing stopwords: ['lalaki', 'arestado', 'matapos', 'magpaputok', 'baril', 'iinuman', 'qc']
# Sentence after removing stopwords: ['singil', 'tubig', 'tataas', 'pagpasok', 'taong', '2023']
# Sentence after removing stopwords: ['paglipat', 'pnp', 'custody', 'gunman', 'percy', 'lapid', 'slay', 'aprub', 'korte']
# Sentence after removing stopwords: ['pnp', 'naka', 'heightened', 'alert']
# Sentence after removing stopwords: ['2', 'online', 'sellers', 'covid', '19', 'test', 'kits', 'arestado', 'maynila']
# Sentence after removing stopwords: ['frat', 'member', 'humingi', 'tawad', 'kay', 'john', 'matthew', 'salilig', "'sorry", "talaga'"]
# Sentence after removing stopwords: ['bangkay', 'college', 'student', 'natagpuan', 'cavite']
# Sentence after removing stopwords: ['pbbm', 'nakatanggap', 'very', 'good', 'net', 'satisfaction', 'rating', 'sws']
# Sentence after removing stopwords: ['enrique', 'gil', 'nananatiling', 'kapamilya', 'pumirma', 'exclusive', 'contract', 'abs', 'cbn']
# Sentence after removing stopwords: ['look', 'dating', 'gabinete', 'noynoy', 'nagpakuha', 'huling', 'larawan', 'kasama', 'labi', 'namayapang', 'pangulo']
# Sentence after removing stopwords: ['ilang', 'senador', 'wi', 'nelcome', 'planong', 'expansion', 'philhealth', 'hemodialysis', 'coverage']
# Sentence after removing stopwords: ['araw', 'pagkabuhay', 'gamitin', 'magbago', 'magpakabuti', 'marcos']
# Sentence after removing stopwords: ['manila', 'lgu', 'pinag', 'aaralang', 'ibalik', 'face', 'mask', 'rule']
# Sentence after removing stopwords: ['nakakaaliw', 'tnt', 'video', 'sim', 'registration', 'viral']
# Sentence after removing stopwords: ['maynilad', 'nagbabala', 'mas', 'matagal', 'water', 'interruption', 'simula', 'april', '1']
# Sentence after removing stopwords: ['gobyerno', 'makipagtulungan', 'fbi', 'pagpapauwe', 'kay', 'cong', 'teves']
# Sentence after removing stopwords: ['ex', 'pnp', 'deputy', 'chief', 'for', 'ops', 'pumalag', 'kay', 'abalos', 'p6', '7', 'bilyon', 'shabu', 'cover', 'up']
# Sentence after removing stopwords: ['pagtaas', 'presyo', 'produktong', 'baboy', 'iniimbestigahan', 'gobyerno']
# Sentence after removing stopwords: ['octa', 'mas', 'maraming', 'pinoy', 'tiwala', 'kay', 'pangulong', 'bongbong']
# Sentence after removing stopwords: ['anti', 'taray', 'bill', 'government', 'workers', 'isinulong', 'senado']
# Sentence after removing stopwords: ['hosting', 'pilipinas', 'fiba', 'asia', 'cup', 'tuloy']
# Sentence after removing stopwords: ['7', 'key', 'bilateral', 'agreements', 'nakatakdang', 'lagdaan', 'japan', 'visit', 'pbbm']
# Sentence after removing stopwords: ['marcos', 'inatasan', 'dswd', 'ituloy', 'calibrate', '4ps']
# Sentence after removing stopwords: ['daan', 'daang', 'residente', 'lopez', 'quezon', 'inilikas', "'amang'"]
# Sentence after removing stopwords: ['dpwh', 'magsasagawa', 'weekend', 'road', 'reblocking']
# Sentence after removing stopwords: ['criteria', 'a4', 'covid', '19', 'vaccination', 'simple']
# Sentence after removing stopwords: ['ayuda', 'tsuper', 'pasahero', 'ipaglalaban', 'dotr', 'ltfrb', 'tugade']
# Sentence after removing stopwords: ['opisyal', 'sugar', 'regulatory', 'administration', 'nagbitiw', 'puwesto']
# Sentence after removing stopwords: ['lingkod', 'kapamilya', 'nakiisa', 'blood', 'donation', 'taytay']
# Sentence after removing stopwords: ['marcos', 'pinatawag', 'chinese', 'envoy', 'upang', 'ipahayag', 'pagkabahala', 'china', 'vs', 'pcg', 'filipino', 'fishermen', 'wps']
# Sentence after removing stopwords: ['number', 'coding', 'muling', 'ipinatutupad', 'metro', 'manila', 'disyembre', '1']
# Sentence after removing stopwords: ['p4', 'b', 'halaga', 'hinihinalang', 'shabu', 'nasa', 'tea', 'bag', 'nasabat', 'baguio', 'city']
# Sentence after removing stopwords: ['mambabatas', 'isinusulong', 'pagsasama', 'electric', 'motorcycle', 'bagong', 'eo', 'nagpapataw', 'zero', 'import', 'tariff', 'e', 'motorcycles']
# Sentence after removing stopwords: ['kaso', 'dengue', 'quezon', 'city', 'tumaas', '176', 'percent']
# Sentence after removing stopwords: ['sc', 'pinagtibay', 'pagiging', 'legal', 'train', 'law']
# Sentence after removing stopwords: ['philippines', 'us', 'balikatan', 'arangkada']
# Sentence after removing stopwords: ['ilang', 'lugar', 'luzon', 'visayas', 'isinailalim', 'signal', 'no', '1', 'bagyong', 'amang']
# Sentence after removing stopwords: ['james', 'yap', 'pagsabak', 'politika', 'hamon', 'baguhang', 'matitinag']
# Sentence after removing stopwords: ['95', '300', 'katao', 'nasalanta', "'amang'", 'ndrrmc']
# Sentence after removing stopwords: ['lalaki', 'patay', 'matapos', 'pagbabarilin', 'nakaalitan', 'umanong', 'tnvs', 'rider']
# Sentence after removing stopwords: ['allowance', 'guro', 'darating', 'barangay', 'sk', 'elections', 'tataasan', 'comelec']
# Sentence after removing stopwords: ['p150', 'umento', 'sahod', 'private', 'sector', 'iginiit']
# Sentence after removing stopwords: ['isyu', 'papel', 'lisensiya', 'ikinadismaya', 'motorista']
# Sentence after removing stopwords: ['bongbong', 'marcos', 'negatibo', 'cocaine']
# Sentence after removing stopwords: ["'isa", "utak'", 'marvin', 'miranda', 'pinakakasuhan', '9', 'counts', 'murder', 'degamo', 'slay']
# Sentence after removing stopwords: ['ilang', 'mambabatas', 'hiniling', 'concerned', 'agencies', 'ganap', 'ipatupad', 'the', 'centenarians', 'act', 'of', '2016']
# Sentence after removing stopwords: ['suporta', 'electric', 'vehicles', 'sagot', 'tumataas', 'presyo', 'langis', 'umiigting']
# Sentence after removing stopwords: ['cpp', 'kinumpirma', 'pagkamatay', 'nina', 'benito', 'wilma', 'tiamzon', "'tinorture'", 'diumano']
# Sentence after removing stopwords: ['speaker', 'romualdez', "'di", 'hahadlangan', 'imbestigasyon', 'ethics', 'panel', 'kay', 'rep', 'arnie', 'teves']
# Sentence after removing stopwords: ['hpg', 'chief', 'nagbitiw', 'matapos', 'sibakin', 'puwesto', 'sariling', 'anak', 'nasangkot', 'kontrobersiya']
# Sentence after removing stopwords: ['sec', 'remulla', 'optimismo', 'malapit', 'maresolba', 'kaso', 'pagpatay', 'kay', 'gov', 'degamo']
# Sentence after removing stopwords: ['taong', 'transition', 'period', 'i', 'phase', 'out', 'pogo', 'sapat', 'ayon', 'senador']
# Sentence after removing stopwords: ['pang', 'kaso', 'vs', 'de', 'dedesisyunan']
# Sentence after removing stopwords: ['batang', 'nasa', 'loob', 'delivery', 'box', 'motorsiklo', 'nakunan', 'video']
# Sentence after removing stopwords: ['pink', 'netizens', 'nanawagan', 'isama', 'monsour', 'del', 'rosario', 'senatorial', 'slate', 'leni', 'kiko', 'tandem']
# Sentence after removing stopwords: ['bagyong', 'odette', 'lalong', 'lumalakas', 'signal', 'no', '2', 'itinaas', 'ilang', 'parte', 'surigao']
# Sentence after removing stopwords: ['no', 'permit', 'no', 'exam', 'ban', 'magpapasara', 'maraming', 'pribadong', 'eskwelahan']
# Sentence after removing stopwords: ['doh', 'iginiit', 'pagsusuot', 'face', 'mask', 'christmas', 'gatherings', 'events']
# Sentence after removing stopwords: ['madre', 'itinuturing', 'pinakamatandang', 'tao', 'mundo', 'pumanaw', 'edad', '118']
# Sentence after removing stopwords: ['p162m', 'jackpot', 'grand', 'lotto', '6', '55', 'nasungkit']
# Sentence after removing stopwords: ['malakanyang', 'nalungkot', 'pagbagsak', 'pilipinas', 'world', 'happiness', 'report', 'ranking']
# Sentence after removing stopwords: ['deped', 'palalakasin', 'numeracy', 'literacy', 'programs', 'revised', 'k', 'to', '12', 'program']
# Sentence after removing stopwords: ['harry', 'roque', 'naospital', 'covid', '19']
# Sentence after removing stopwords: ['padilla', 'nagbanta', 'aalis', 'pdp', 'susuportahan', 'partido', 'cha', 'cha']
# Sentence after removing stopwords: ['2', 'kabataan', 'inaresto', 'magprotesta', 'vs', 'balikatan', 'edca', 'us', 'embassy', 'pnp']
# Sentence after removing stopwords: ['e', 'travel', 'system']
# Sentence after removing stopwords: ['panukalang', 'rightsizing', 'pamahalaan', 'lusot', 'kamara']
# Sentence after removing stopwords: ['milyun', 'milyong', 'pisong', 'halaga', 'droga', 'umano', 'nasabat', 'condo', 'unit', 'mandaluyong', 'syrian', 'national', 'arestado']
# Sentence after removing stopwords: ['sec', 'gatchalian', 'pinag', 'iingat', 'publiko', 'vs', 'text', 'scam', 'unclaimed', 'senior', 'allowances']
# Sentence after removing stopwords: ['6', '6', 'magnitude', 'lindol', 'yumanig', 'samar', 'bicol']
# Sentence after removing stopwords: ['bi', 'naalarma', 'kaugnay', 'talamak', 'totoo', 'ilegal', 'nakuhang', 'philippine', 'passport']
# Sentence after removing stopwords: ['83', 'pilipino', 'nasa', 'death', 'row', 'abroad', 'ayon', 'dfa']
# Sentence after removing stopwords: ['52', 'pinoy', "'disapprove'", 'pagtugon', 'marcos', 'jr', 'inflation', 'pulse', 'asia']
# Sentence after removing stopwords: ['security', 'officers', 'naia', 'nahuli', 'cam', 'umano', 'pera', 'papaalis', 'turistang', 'thai']
# Sentence after removing stopwords: ['magkapatid', 'senior', 'citizen', 'natagpuang', 'patay', 'maynila', 'suspek', 'arestado']
# Sentence after removing stopwords: ['csc', 'chief', 'nanawagan', 'pagkakaisa', 'gender', 'mainstreaming', 'asean', 'region']
# Sentence after removing stopwords: ['tnvs', 'driver', 'stephen', 'speaks', 'pinalusot', 'umano', 'violation', 'matapos', 'magpa', 'selfie', 'banda', 'enforcer', 'mmda', 'iimbestiga']
# Sentence after removing stopwords: ['awtorisadong', 'koleksyon', 'prize', 'fund', 'taxes', 'umabot', 'p4', 'bilyon']
# Sentence after removing stopwords: ['viral', 'pagsagasa', 'truck', 'enforcer', 'nagmamando', 'trapiko', 'quezon', 'city', 'iimbestigahan']
# Sentence after removing stopwords: ['bagsik', 'neneng', 'ramdam', 'rin', 'pinas', 'ilang', 'klase', 'northern', 'luzon', 'suspendido']
# Sentence after removing stopwords: ['pulse', 'asia', '6', '10', 'pinoy', 'ayaw', 'magpabakuna', 'covid', '19']
# Sentence after removing stopwords: ['pnp', 'chief', 'itinanggi', "umano'y", 'cover', 'up', 'manila', 'drug', 'raid']
# Sentence after removing stopwords: ['grupo', 'pumalag', 'angkat', 'buffer', 'stock', 'nfa', 'rice']
# Sentence after removing stopwords: ['49', 'pilipino', 'naniniwalang', 'gaganda', 'kalidad', 'pamumuhay', 'susunod', '12', 'buwan', 'sws']
# Sentence after removing stopwords: ['pagasa', 'bagyo', 'asahan', 'kalat', 'kalat', 'ulan', 'ilang', 'lugar']
# Sentence after removing stopwords: ['jane', 'de', 'leon', 'binanatan', 'netizen', 'binuhay', 'pagiging', 'kakampink', 'let', 's', 'boycott', 'darna']
# Sentence after removing stopwords: ['amnesty', 'international', 'nanawagan', 'independent', 'investigation', 'lapid', 'slay', 'case']
# Sentence after removing stopwords: ['bulkang', 'taal', 'nakapagtala', '55', 'volcanic', 'quakes']
# Sentence after removing stopwords: ['dating', 'kitchen', 'helper', 'wagi', 'p75', '2m', 'grand', 'lotto', '6', '55']
# Sentence after removing stopwords: ['maynilad', 'ilang', 'bahagi', 'ncr', 'cavite', 'mawawalan', 'tubig', 'april', '23']
# Sentence after removing stopwords: ['lpa', 'magpapaulan', 'vismin', 'mainit', 'paparating', 'pagasa']
# Sentence after removing stopwords: ['apor', 'nasa', 'granular', 'lockdown', 'payagang', 'makapagtrabaho', 'ayon', 'kay', 'marcos']
# Sentence after removing stopwords: ['korte', 'lugar', 'isasailalim', 'gcq', 'bubuksan', 'simula', 'mayo', '17']
# Sentence after removing stopwords: ['marcos', 'target', '2027', 'rice', "'self", "sufficiency'", 'posible', 'liberalisasyon', 'tatalikuran', 'grupo']
# Sentence after removing stopwords: ['government', 'agencies', 'aaksyon', 'reklamo', 'loob', 'tatlong', 'araw', 'paiimbestigahan', 'arta', 'ombudsman']
# Sentence after removing stopwords: ['panoorin', 'karen', 'meets', 'kaladkaren']
# Sentence after removing stopwords: ['water', 'level', 'angat', 'dam', '6', 'patuloy', 'pagbaba']
# Sentence after removing stopwords: ['dayuhang', 'pasahero', 'naia', 'nawalan', 'p50k', 'naibalik', 'agad', 'airport', 'staff']
# Sentence after removing stopwords: ['lalaking', 'nagpapanggap', 'koneksyon', 'makati', 'city', 'hall', 'huli', 'swindling']
# Sentence after removing stopwords: ['4', 'central', 'luzon', 'areas', 'nagtala', 'pinakamataas', 'bagong', 'kaso', 'covid', '19']
# Sentence after removing stopwords: ['one', 'strike', 'policy', 'magdudulot', 'blacklisting', 'persona', 'non', 'grata', 'taong', 'nagsasagawa', 'hazing']
# Sentence after removing stopwords: ['speech', 'japan', 'prime', 'minister', 'kishida', 'hinagisan', 'smoke', 'bomb']
# Sentence after removing stopwords: ['globe', 'libreng', 'tawag', 'libreng', 'wifi', 'nakahanda', 'bagyong', 'kiko']
# Sentence after removing stopwords: ['alamin', 'presyo', 'bulaklak', 'dangwa', 'market', 'kakaibang', 'pangregalo', 'valentine', 's', 'day']
# Sentence after removing stopwords: ['rider', 'patay', 'pamamaril', 'ntilde', 'aque', 'insidente', 'nahuli', 'cam']
# Sentence after removing stopwords: ['lrt', 'papayagan', 'pagsakay', 'pets', 'simula', 'feb', '1']
# Sentence after removing stopwords: ['person', 'of', 'interest', 'idinawit', 'pagkamatay', 'john', 'mathew', 'salilig', 'natagpuang', 'patay']
# Sentence after removing stopwords: ['dmw', 'magpapadala', 'fact', 'finding', 'team', 'kuwait', 'kasunod', 'brutal', 'pagkamatay', 'jullebee', 'ranara']
# Sentence after removing stopwords: ['dating', 'pangulong', 'marcos', 'tulay', 'iibigan', 'magulang', 'greco', 'belgica']
# Sentence after removing stopwords: ['17', 'anyos', 'dalagita', '10', 'araw', 'guho', 'nasagip', 'turkey']
# Sentence after removing stopwords: ['sec', 'abalos', 'tiniyak', 'buong', 'suporta', 'bagong', 'hepe', 'pnp', 'pgen', 'benjamin', 'acorda']
# Sentence after removing stopwords: ['mahigit', 'daang', 'grupo', 'indibidwal', 'umapela', 'senado', 'umapela', 'rejection', 'rcep']
# Sentence after removing stopwords: ['paglikas', 'pilipino', 'sudan', 'inaayos', 'pamahalaan']
# Sentence after removing stopwords: ['manny', 'pacquiao', 'chavit', 'singson', 'nagkabati', 'because', 'friendship', 'is', 'stronger', 'than', 'politics']
# Sentence after removing stopwords: ['pagpapatupad', 'bagong', 'e', 'travel', 'system', 'lalawakan', 'simula', 'abril', '15']
# Sentence after removing stopwords: ['da', 'nagtakda', 'p125', 'kada', 'kilo', 'srp', 'imported', 'pulang', 'sibuyas']
# Sentence after removing stopwords: ['babaeng', 'pumalag', 'snatcher', 'naagaw', 'motor']
# Sentence after removing stopwords: ['dalawang', 'karagdagang', 'reklamo', 'suspek', 'salilig', 'case', 'submitted', 'for', 'resolution', 'doj']
# Sentence after removing stopwords: ['umano', 'y', 'korupsyon', 'dswd', 'doe', 'ibinunyag', 'pacquiao']
# Sentence after removing stopwords: ['us', 'australian', 'military', 'planes', 'nasa', 'pinas', 'balikatan']
# Sentence after removing stopwords: ['nanuhol', 'yarn', 'traffic', 'violation', 'stephen', 'speaks', 'iimbestigahan', 'mmda']
# Sentence after removing stopwords: ['covid', '19', 'positivity', 'rate', 'ncr', 'biglang', 'tumaas', 'ngayong', 'holy', 'week', 'octa']
# Sentence after removing stopwords: ['paeng', 'tapos', 'manalasa', 'bansa', 'pang', 'bagyo', 'nagbabadya']
# Sentence after removing stopwords: ['utang', 'gobyerno', 'lumobo', 'p13', '7t', 'noong', 'enero']
# Sentence after removing stopwords: ['kwento', 'marc', 'logan', 'video', "'tsismosong'", 'aso', 'pusa']
# Sentence after removing stopwords: ['da', 'usec', 'panganiban', 'itinalagang', 'oic', 'sra']
# Sentence after removing stopwords: ['dnd', 'pumalag', 'banta', 'chinese', 'envoy', 'lagay', 'ofws', 'taiwan']
# Sentence after removing stopwords: ['hong', 'raffle', '500k', 'plane', 'tickets', 'libreng', 'vouchers']
# Sentence after removing stopwords: ['7', 'pulis', 'patay', '22', 'sugatan', 'karambola', '3', 'sasakyan', 'misamis', 'oriental']
# Sentence after removing stopwords: ['carlo', 'biado', 'kampeon', '2021', 'us', 'open', 'pool']
# Sentence after removing stopwords: ['panininghal', 'harry', 'roque', 'doktor', 'ikinadismaya', 'nina', 'angel', 'ogie']
# Sentence after removing stopwords: ['inflation', 'nitong', 'marso', 'bumaba', '7', '6', '8', '6', 'noong', 'pebrero', 'psa']
# Sentence after removing stopwords: ['lugi', 'occidental', 'mindoro', 'power', 'crisis', 'milyon', 'milyon']
# Sentence after removing stopwords: ['kfc', 'branch', 'pasig', 'ipinasara', 'reklamo', 'mayor', 'vico', 'sotto', 'grabe', 'yung', 'kapal', 'sebo']
# Sentence after removing stopwords: ['imbentaryo', 'bigas', 'bansa', 'bumagsak', 'noong', 'nakaraang', 'buwan', 'psa']
# Sentence after removing stopwords: ['5', 'house', 'leaders', 'naghain', 'panukala', 'bigyan', 'kapangyarihan', 'pbbm', 'suspendihin', 'philhealth', 'rate', 'hikes']
# Sentence after removing stopwords: ['duterte', 'makikipag', 'debate', 'kay', 'carpio']
# Sentence after removing stopwords: ['lto', 'driver', 's', 'license', 'mae', 'expire', 'simula', 'april', '24', 'palalawigin', 'multa', 'late', 'penalty', 'di', 'muna', 'sisingilin']
# Sentence after removing stopwords: ['mangingisda', 'magsasaka', 'inalerto', 'da', 'kay', 'amang']
# Sentence after removing stopwords: ['kampo', 'pimentel', 'pacquiao', 'susuportahan', 'sakaling', 'tumakbong', 'presidente', '2022']
# Sentence after removing stopwords: ['toni', 'binanatan', 'netizens', 'interview', 'kay', 'bongbong', 'such', 'a', 'disappointment']
# Sentence after removing stopwords: ['sec', 'remulla', 'tiniyak', 'makakaligtas', 'imbestigasyon', 'pamamaslang', 'kay', 'gov', 'degamo', '8']
# Sentence after removing stopwords: ['4', '10', 'detainees', 'tumakas', 'pasay', 'jail', 'nasakote']
# Sentence after removing stopwords: ['patong', 'patong', 'trabaho', 'public', 'school', 'teachers', 'solusyonan']
# Sentence after removing stopwords: ['26', 'lugar', 'puerto', 'galera', 'nakitaan', 'langis', 'grasa']
# Sentence after removing stopwords: ['30', '3', 'million', 'philsys', 'ids', 'naipadala', 'psa']
# Sentence after removing stopwords: ['pagasa', 'lpa', 'patuloy', 'lumalapit', 'mindanao', 'mababa', 'tsansa', 'bagyo']
# Sentence after removing stopwords: ['ex', 'bucor', 'chief', 'bantag', 'zulueta', 'pina', 'aaresto', 'korte', 'kaugnay', 'lapid', 'slay', 'case']
# Sentence after removing stopwords: ['sunod', 'sunod', 'atake', 'gov', 't', 'officials', 'isolated', 'cases', 'ayon', 'pnp']
# Sentence after removing stopwords: ['unidentified', 'flying', 'object', 'himpapawid', 'canada', 'pinabagsak', 'us', 'fighter', 'jet']
# Sentence after removing stopwords: ['batang', 'aaral', 'nagiging', 'zombie', 'distance', 'learning', 'system', 'sen', 'imee', 'marcos']
# Sentence after removing stopwords: ['prc', 'licensure', 'exam', 'mayo', 'hunyo', 'tuloy']
# Sentence after removing stopwords: ['sakay', 'bumagsak', 'cessna', 'plane', 'bicol', 'kumpirmadong', 'nasawi', 'mdash', 'mayor']
# Sentence after removing stopwords: ['manlalakbay', '7', 'bansa', 'africa', 'bawal', 'pumasok', 'pinas']
# Sentence after removing stopwords: ['dswd', 'pinalawig', 'cash', 'for', 'work', 'program', 'oriental', 'mindoro', 'apektado', 'oil', 'spill']
# Sentence after removing stopwords: ['water', 'crisis', 'hinaharap', 'umano', 'bansa', 'ayon', 'kay', 'pangulong', 'marcos']
# Sentence after removing stopwords: ['grupo', 'kinastigo', "'pang", "iismol'", 'afp', 'epekto', 'balikatan', 'pangingisda']
# Sentence after removing stopwords: ['miss', 'earth', '2022', 'suportado', 'tariff', 'breaks', 'electric', 'vehicles']
# Sentence after removing stopwords: ['paggamit', 'sara', 'duterte', 'chopper', 'araw', 'araw', 'fake', 'news', 'daw', 'ayon', 'vp', 'spokesperson']
# Sentence after removing stopwords: ['suspek', 'tila', 'nilito', 'umano', 'hinggil', 'totoong', 'target', 'degamo', 'slay', 'case', 'pulisya']
# Sentence after removing stopwords: ['house', 'sinimulan', 'plenary', 'deliberations', 'panukalang', 'cha', 'cha']
# Sentence after removing stopwords: ['doh', 'nakapag', 'detect', '671', 'bagong', 'kaso', 'omicron', 'subvariants']
# Sentence after removing stopwords: ['san', 'beda', 'university', 'kakampink', 'rin']
# Sentence after removing stopwords: ['klase', 'occidental', 'mindoro', 'walangpasok', '3', 'araw']
# Sentence after removing stopwords: ['psa', 'nakapagbigay', 'mahigit', '40', 'million', 'national', 'id', 'ngayong', 'enero']
# Sentence after removing stopwords: ['ama', 'cambodia', 'tinamaan', 'bird', 'flu', 'batang', 'babae', 'patay', 'w', 'h']
# Sentence after removing stopwords: ['ilang', 'pulis', 'umano', 'ginamit', 'spotters', 'pagpatay', 'negros', 'oriental']
# Sentence after removing stopwords: ['tigil', 'pasada', 'jeep', 'itutuloy', 'march', '6', '12']
# Sentence after removing stopwords: ['pilot', 'testing', 'balik', 'eskuwelahan', 'inaprubhan', 'pangulong', 'duterte']
# Sentence after removing stopwords: ['2', 'mataas', 'opisyal', 'gobyerno', 'ipapapatay', 'rep', 'teves']
# ...
# Sentence after removing stopwords: ['ulan', 'tumila', 'tapos', 'biglang', 'umaraw', 'climate', 'change', 'iyun', 'iyun', 'climate', 'change', 'natin', 'gawing', 'biro', 'di', 'naman', 'seryoso']
# Sentence after removing stopwords: ['groom', 'naghahatid', 'invitations', 'nalalapit', 'kasal', 'binawian', 'buhay', 'matapos', 'maaksidente']
# Sentence after removing stopwords: ['lalaking', 'nagbebenta', 'sponge', 'loob', '13', 'years', 'graduate', 'kolehiyo']
# Sentence after removing stopwords: ['naka', 'bike', 'delivery', 'rider', 'tinulungan', "'dating", 'batang', 'kalye', 'ngayo', 'y', 'tumutulong', "na'"]
# Sentence after removing stopwords: ['daga', 'nakapasok', 'atm', 'machine', 'nginatngat', 'pera', 'loob']
# Sentence after removing stopwords: ['5', 'rescuers', 'bulacan', 'nasawi', 'tungkulin', 'kinilalang', 'bayani', 'paparangalan']
# Sentence after removing stopwords: ['dennis', 'padilla', 'umaming', 'nagkasala', 'gustong', 'makapiling', 'anak', 'marjorie']
# Sentence after removing stopwords: ['bank', 'mngr', 'kilalang', 'bangko', 'inireklamo', 'unauthorized', 'withdrawals', 'bank', 'accounts', 'kliyente']
# Sentence after removing stopwords: ['ruffa', 'binahagi', 'muling', 'pagkakausap', 'yilmaz', 'yilmaz', 'lang', 'yung', 'lalaki', 'iniiyakan', 'rin']
# Sentence after removing stopwords: ['saging', 'halos', 'kasing', 'haba', 'braso', 'tao', 'natagpuan', 'pangasinan']
# Sentence after removing stopwords: ['retired', 'manager', 'tropical', 'hut', 'masayang', 'nagdiwang', "'father's", "day'", 'dating', 'pinagtatrabahuhan']
# Sentence after removing stopwords: ['hala', 'nlrc', 'ipatanggal', 'senado', 'sen', 'tulfo', 'taong', 'bayan', 'people', 'power', 'daw']
# Sentence after removing stopwords: ['pasang', 'awa', 'laging', 'bagsak', 'estudyante', 'topnotcher', 'nursing', 'board', 'exam']
# Sentence after removing stopwords: ['grabe', 'nangyari', 'turkey', 'lang', 'feb', '6', '2023', 'pray', 'po', 'nating', 'lagi', 'po', 'handa', 'iingat']
# Sentence after removing stopwords: ['binata', 'winakasan', 'buhay', 'pananakot', 'inutangan', 'loan', 'apps']
# Sentence after removing stopwords: ['anak', 'basurero', 'ipinagmalaki', 'amang', 'napagtapos', 'aaral']
# Sentence after removing stopwords: ['nakaraos', 'proud', 'repeater', 'ganap', 'civil', 'engineer']
# Sentence after removing stopwords: ['dj', 'loonyo', 'binuweltahan', 'janine', 'berdin', 'matapos', 'idawit', 'pangalan', 'larawan', "'airport'", 'meme']
# Sentence after removing stopwords: ['kat', 'alano', 'pinapatamaan', 'people', 'will', 'cancel', 'you', 'for', 'cake', 'but', 'celebrate', 'you', 'for', 'rap3']
# Sentence after removing stopwords: ['ina', 'negros', 'occidental', 'parehas', 'centenarian']
# Sentence after removing stopwords: ['raffy', 'tulfo', 'binatikos', 'netizen', 'matapos', 'maliitin', '16m', 'bumoto', 'kay', 'pangulong', 'duterte']
# Sentence after removing stopwords: ['batikang', 'aktres', 'tinalbugan', 'kasabayan', 'showbiz', 'edad', '40', 'nabuntis']
# Sentence after removing stopwords: ['matandang', 'lalaki', 'niloko', 'kinuha', 'atm', 'pension', 'puno', 'natutulog']
# Sentence after removing stopwords: ['teacher', 'minura', 'estudyanteng', 'tinutulungan', 'makapasa', 'naglabas', 'sama', 'loob']
# Sentence after removing stopwords: ['the', 'ren', 'ai', 'reef', 'is', 'part', 'of', 'china', 's', 'nansha', 'islands', 'on', 'february', '6', 'a', 'philippine', 'coast', 'guard', 'vessel', 'intruded', 'into', 'the', 'waters', 'off', 'the', 'ren', 'ai', 'reef', 'without', 'chinese', 'permission', 'in', 'accordance', 'with', 'china', 's', 'domestic', 'law', 'and', 'international', 'law', 'including', 'the', 'united', 'nations', 'convention', 'on', 'the', 'law', 'of', 'the', 'sea', 'the', 'china', 'coast', 'guard', 'ship', 'upheld', 'china', 's', 'sovereignty', 'and', 'maritime', 'order', 'and', 'acted', 'in', 'a', 'professional', 'and', 'restrained', 'way', 'source', 'china', 'ministry', 'of', 'foreign', 'affairs', 'official', 'website', 'foreign', 'ministry', 'spokesperson', 'wang', 'wenbin', 's', 'regular', 'press', 'conference', 'on', 'february', '13', '2023', 'feb', '13', '2023']
# Sentence after removing stopwords: ['plantita', 'lumabo', 'mata', 'matapos', 'matalsikan', 'dagta', 'halamang']
# Sentence after removing stopwords: ['lolit', 'solis', 'kinuwestiyon', 'kontribusyon', 'nina', 'philip', 'salvador', 'james', 'yap', 'anak', 'ngayong', 'pinagdaraanan', 'kalusugan', 'kris', 'aquino']
# Sentence after removing stopwords: ['19', 'anyos', 'ina', 'bitbit', 'anak', 'nagtatrabaho', 'taga', 'deliver', 'pagkain']
# Sentence after removing stopwords: ['the', 'maggie', 'dela', 'riva', 'story', 'maimpluwensyang', 'tao', 'tinapos', 'buhay']
# Sentence after removing stopwords: ['ex', 'commissioner', 'rowena', 'guanzon', 'resbak', 'kay', 'ruffa', 'that', 'ruffa', 'gutierrez', 'must', 'learn', 'to', 'say', "'congresswoman'"]
# Sentence after removing stopwords: ['kuya', 'kim', 'ipinagmalaki', 'kaniyang', 'anak', 'ngayong', 'lisensyadong', 'piloto']
# Sentence after removing stopwords: ['ina', 'dismayado', 'sinapit', 'anak', 'labis', 'paggamit', 'cellphone', "'i", 'really', 'felt', 'guilty', 'as', 'a', "mom'"]
# Sentence after removing stopwords: ['lola', 'patuloy', 'pagtitinda', 'mais', 'umulan', 'man', 'umaraw']
# Sentence after removing stopwords: ['lalaki', 'nakapagpatayo', 'magandang', 'bahay', 'halagang', '50', '000', 'pesos', 'aircon']
# Sentence after removing stopwords: ['kylie', 'padilla', 'to', 'robin', 'mahal', 'mahal', 'tatay', 'pilipinas', 'mahal', 'nya', 'tao']
# Sentence after removing stopwords: ['akala', 'talaga', 'magaling', 'fbi', 'di', 'hanapin', 'yung', 'wanted', 'pastor', 'apollo', 'quiboloy', 'source', 'krizette', 'laureta', 'chu', 's', 'official', 'facebook', 'page', 'akala', 'talaga', 'magaling', 'fbi', 'dec', '11', '2022']
# Sentence after removing stopwords: ['empleyado', 'nagpasa', 'resignation', 'letter', 'kinaaliwan', 'social', 'media']
# Sentence after removing stopwords: ['amang', 'maigalaw', 'kalahati', 'katawan', 'itinataguyod', 'pamilya', 'mekaniko']
# Sentence after removing stopwords: ['wouldn', 't', 'it', 'be', 'easier', 'confidential', 'funds', 'ibibigay', 'eskwelahan', 'nangangailangan', 'bubong', 'pondo', 'eh', 'you', 'have', 'to', 'remember', 'maglalagay', 'eskwelahan', 'lugar', 'naka', 'earmark', 'yan', 'bagyo', 'dun', 'karatig', 'bayan', 'natamaan', 'bagyo', 'natamaan', 'flash', 'flood', 'nangangailangan', 'source', 'senate', 'of', 'the', 'philippines', 'transcription', 'of', 'senate', 'president', 'juan', 'miguel', 'migz', 'zubiri', 's', 'press', 'conference', 'nov', '7', '2022']
# Sentence after removing stopwords: ['turista', 'boracay', 'siningil', 'umano', 'p16', '000', 'hair', 'braiding']
# Sentence after removing stopwords: ['2', 'anyos', 'bata', 'patay', 'matapos', 'isuksok', 'kutsara', 'extension', 'cord']
# Sentence after removing stopwords: ['magkapatid', 'paslit', 'binalikan', 'nanay', 'bibili', 'lang', 'daw', 'payong']
# Sentence after removing stopwords: ['mas', 'mababa', '16', 'inutang', '2022', 'kumpara', 'taong', '2021', 'patunay', 'epektibo', 'polisiya', 'pangangasiwa', 'budget', 'pagpapababa', 'pagdepende', 'natin', 'utang', 'matugunan', 'pangangailangan', 'natin', 'bansa', 'source', 'bongbong', 'marcos', 'official', 'facebook', 'page', 'mas', 'mababa', '16', 'inutang', 'march', '13', '2023']
# Sentence after removing stopwords: ['customer', 'sikat', 'restaurant', 'muntik', 'makakain', 'ipis']
# Sentence after removing stopwords: ['lola', 'nakapagtapos', 'edad', '62', 'pinagsasabay', 'aaral', 'aalaga', 'apo', 'pagtitinda']
# Sentence after removing stopwords: ['babala', 'magulang', 'bata', 'dinanas', 'masamang', 'epekto', 'sobrang', 'pagamit', 'gadgets']
# Sentence after removing stopwords: ['dating', 'tampulan', 'tukso', 'laging', 'umiiyak', 'paguwi', 'galing', 'eskwela', "modelo't", 'sariling', 'negosyo']
# Sentence after removing stopwords: ['simple', 'praktikal', 'kasal', 'magkasintahang', 'hikers', 'umabot', '4', 'libong', 'piso']
# Sentence after removing stopwords: ['kasamahan', 'jovelyn', 'galleno', 'simbahan', 'sinabing', 'umano', 'nakasakay', 'innova', 'nitong', 'agosto', '16']
# Sentence after removing stopwords: ['incoming', 'grade', '12', 'student', 'naghahanap', 'aampon', 'magpapa', 'aral']
# Sentence after removing stopwords: ['pinoy', 'memories', 'inabutan', 'mo', 'ba', 'popular', 'darigold', 'milk']
# Sentence after removing stopwords: ['mamahaling', 'crystal', 'natagpuan', 'puno', 'balete', 'antique']
# Sentence after removing stopwords: ['anna', 'feliciano', 'tuwang', 'tuwa', 'tinanggap', 'sorpresang', 'brand', 'new', 'car', 'kay', 'kuya', 'wil']
# Sentence after removing stopwords: ['vocalist', 'bandang', 'the', 'juans', 'itinanggi', 'bintang', 'pagsabi', 'b', 'b', 'bongbong']
# Sentence after removing stopwords: ['kontrabida', 'ngunit', 'mukhang', 'nakakatawa', 'nangyari', 'kay', 'joaquin', 'buwaya', 'fajardo']
# Sentence after removing stopwords: ['marian', 'rivera', 'naniniwala', 'kakayahan', 'jane', 'de', 'leon', 'darna']
# Sentence after removing stopwords: ['bukod', '10m', 'manny', 'pangilinan', 'handang', 'ibigay', 'hiling', 'hidilyn']
# Sentence after removing stopwords: ['math', 'teacher', 'piniling', 'ring', 'ipagpatuloy', 'pagtuturo', 'kabila', 'pagkawala', 'kanang', 'mata', 'tumor']
# Sentence after removing stopwords: ['marcelito', 'pomoy', 'nagbahagi', 'mensahe', 'namayapang', 'kaibigan', 'jovit', 'baldivino']
# Sentence after removing stopwords: ['ingat', 'ketchup', 'm0dus', 'laganap', 'pandemya']
# Sentence after removing stopwords: ['katapatan', 'dating', 'taxi', 'driver', 'binigyan', 'full', 'scholarship', 'australia', 'pasaherong', 'businessman']
# Sentence after removing stopwords: ['dating', 'sikat', 'dancer', 'kuya', 'wil', 'luningning', 'buhay']
# Sentence after removing stopwords: ['kahera', 'pilit', 'pinaaming', 'nagnakaw', 'pera', 'tanggal', 'trabaho', 'kinuha', 'sweldo']
# Sentence after removing stopwords: ['batang', 'camsur', 'pinuri', 'social', 'media', 'husay', 'guhit']
# Sentence after removing stopwords: ['gaano', 'kayaman', 'andrew', 'e', 'nakamit', 'king', 'of', 'tagalog', 'rap', 'muntik', 'siyang', 'makulong']
# Sentence after removing stopwords: ['nagpapanggap', 'delivery', 'boy', 'shopee', 'umubra', 'alistong', 'customer']
# Sentence after removing stopwords: ['binatang', 'nagtitinda', 'leche', 'flan', 'iniipon', 'kita', 'pampa', 'opera', 'pang', 'matrikula']
# Sentence after removing stopwords: ['aksyon', 'maraming', 'tao', 'lalo', 'kabataan', 'pagliligo', 'gabi', 'mataas', 'rate', 'stroke', 'biglang', 'pagbabago', 'presyon', 'dugo']
# Sentence after removing stopwords: ['jayda', 'anak', 'nina', 'jessa', 'dingdong', 'avanzado', 'sasabak', 'rin', 'arte']
# Sentence after removing stopwords: ['sikat', 'supermarket', 'ibinabawas', 'umano', 'naibentang', 'turon', 'sahod', 'empleyado']
# Sentence after removing stopwords: ['asawang', 'bulag', 'patuloy', 'lumalaban', 'itinataguyod', '8', 'anak']
# Sentence after removing stopwords: ['seller', 'nahulog', 'putikan', 'nagdeliver', 'naglabas', 'saloobin', 'nambabarat', 'free', 'delivery', 'fee']
# Sentence after removing stopwords: ['balik', 'tanaw', 'eat', 'bulaga', 'host', 'jose', 'manalo', 'boyoyong', 'clowns']
# Sentence after removing stopwords: ['pambansang', 'bangkay', 'jose', 'clemente', 'kahanga', 'hanga', 'pala', 'talento', 'pasukin', 'showbiz']
# Sentence after removing stopwords: ['proud', 'anak', 'iniaalay', 'pagtatapos', 'kolehiyo', 'inang', 'problema', 'iisip']
# Sentence after removing stopwords: ['kontrobersyal', 'celebrity', "'cheating'", 'breakups', 'naaalala', 'niyo', 'ba']
# Sentence after removing stopwords: ['zsa', 'zsa', 'padilla', 'ipinasilip', 'napakalawak', 'lupain', 'comedy', 'king', 'dolphy', 'dolphyville']
# Sentence after removing stopwords: ['ama', 'nahilo', 'nahimatay', 'paglalako', 'karga', 'anak']
# Sentence after removing stopwords: ['kapapasok', 'lang', 'sawakas', 'pres', 'marcos', 'kina', 'usap', 'nasi', 'soj', 'remulla', 'disisyon', 'tangal', 'nasa', 'pwesto']
# Sentence after removing stopwords: ['lalaking', 'putol', 'kalahating', 'katawan', 'hinangaan', 'netizens', 'pagiging', 'masipag', 'kabila', 'kalagayan']
# Sentence after removing stopwords: ['pinay', 'helper', 'malaysia', 'binigyan', '100k', 'gamit', 'pang', 'paayos', 'bahay', 'mabait', 'employer']
# Sentence after removing stopwords: ['sobrang', 'yaman', 'pala', 'michael', 'de', 'mesa', 'maswerte', 'asawa', '13', 'taon', 'edad']
# Sentence after removing stopwords: ['2', 'year', 'old', 'baby', 'iniwan', 'magulang', 'loob', 'sasakyan', 'iinuman']
# Sentence after removing stopwords: ['magnanakaw', 'tinanggihan', 'perang', 'ibinibigay', 'matanda', 'hinalikan', 'noo', 'upang', 'kumalma']
# Sentence after removing stopwords: ['garbage', 'collector', 'napagtapos', 'panganay', 'kolehiyo', 'aaral', 'architect', 'guro', 'highschool']
# Sentence after removing stopwords: ['prof', 'clarita', 'carlos', 'binigyan', 'assignment', 'anak', 'kiko', 'pangilinan', 'kakie']
# Sentence after removing stopwords: ['kwento', 'mister', 'matapos', 'nitong', 'bantayan', 'alagaan', 'anak', 'kinabiliban', 'misis', 'netizens']
# Sentence after removing stopwords: ['barangay', 'official', 'hinarang', 'grab', 'delivery', 'rider', 'daw', 'essential', 'lugaw']
# Sentence after removing stopwords: ['kapansanang', 'ama', 'matagal', 'pinag', 'iipunan', 'pambili', 'sapatos', 'anak']
# Sentence after removing stopwords: ['buhay', 'tinaguriang', 'reyna', 'horror', 'movies', 'lilia', 'cuntapay', 'pala', 'sinapit', 'aktres']
# Sentence after removing stopwords: ['construction', 'worker', 'rumarampa', 'a', 'la', 'catriona', 'gray', 'certified', 'pampa', 'good', 'vibes']
# Sentence after removing stopwords: ['32', 'anyos', 'bulag', 'pagkasilang', 'nakatanggap', 'ayuda', 'matapos', 'manawagan', 'tulong', 'kaniyang', 'tiyahin']
# Sentence after removing stopwords: ['matapos', 'makatanggap', "'goodie", "bag'", 'kapalit', '27', 'taon', 'absent', 'trabaho', 'empleyado', 'biniyayaan', '270k']
# Sentence after removing stopwords: ['maricar', 'reyes', 'nagsalita', 'past', 'scandal', '13', 'years', 'it', 'took', 'a', 'long', 'time', 'to', 'heal', 'and', 'process']
# Sentence after removing stopwords: ['basurera', 'ceo', 'business']
# Sentence after removing stopwords: ['busy', 'wifey', 'mister', 'kakaibang', 'pakulo', 'lang', 'makasama', 'misis', 'bakasyon']
# Sentence after removing stopwords: ['ipinagmamalaking', 'tatay', 'lalaking', 'lasing', 'nagwawala', 'viral', 'video', 'nakilala', 'n', 'yo', 'ba', 'kilala', 'tatay']
# Sentence after removing stopwords: ['asawang', 'nanirahan', 'kulungan', 'baboy', 'nagtulungan', 'nagsikap', 'magkaroon', 'sariling', 'bahay']
# Sentence after removing stopwords: ['pamilya', 'nagpakulong', '84', 'anyos', 'lolo', 'nagsalita', 'sana', 'raw', 'humingi', 'sorry', 'lolo']
# Sentence after removing stopwords: ['netizens', 'nakakaamoy', 'hiwalayan', 'sunshine', 'cruz', 'macky', 'mathay', 'break', 'daw', 'matapos', 'nakakaintrigang', 'post', 'aktres']
# Sentence after removing stopwords: ['nga', 'ba', 'jose', 'mari', 'chan', 'kumakanta', 'christmas', 'in', 'our', 'hearts']
# Sentence after removing stopwords: ['negosyante', 'sasagutin', 'kakailanganing', 'tulong', 'kaso', 'lolo', 'narding']
# Sentence after removing stopwords: ['estudyanteng', 'kapansanan', 'pinagsasabay', 'paglalako', 'itlog', 'chicharon', 'upang', 'matustusan', 'aaral']
# Sentence after removing stopwords: ['remembering', 'marky', 'cielo', 'proud', 'igorot', 'and', 'starstruck', 'ultimate', 'male', 'survivor']
# Sentence after removing stopwords: ['netizen', 'inilabas', 'sekretong', 'galit', 'lang', 'my', 'day', 'kakilala', 'tameme', 'niresbakan']
# Sentence after removing stopwords: ['pinoy', 'vlogger', 'tumulong', 'kay', 'nas', 'daily', 'nagsalita', 'parang', 'ginamit', 'lang', 'naabuso', 'sya', 'kilala']
# Sentence after removing stopwords: ['grabe', 'unang', 'gabi', 'lamay', 'burol', 'kris', 'aquino', 'dinagsa', 'tao', 'kaibigan', 'kamag', 'anak']
# Sentence after removing stopwords: ['tattoo', 'artist', 'walong', 'asawa', 'magkakasamang', 'naninirahan', 'iisang', 'bubong']

# %%
df.iloc[3].Statement
# Out:
# '‘Backdoor entry’ ng Grab sa motorcycle taxi pilot pinaiimbestigahan'

# %%
df.head()
# Out:
#                                            Statement Rating  \
# 0        Lalaki patay sa pamamaril sa Tondo, Maynila   Real
# 1  50 Pinoy na naipit sa kaguluhan sa Sudan, nail...   Real
# 2  #BoyingResign: Netizens galit kay DOJ Chief Re...   Real
# 3  ‘Backdoor entry’ ng Grab sa motorcycle taxi pi...   Real
# 4    Doktor nangangamba na na-mild stroke si De Lima   Real
#
#                                              cleaned  \
# 0               lalaki patay pamamaril tondo maynila
# 1           50 pinoy naipit kaguluhan sudan nailikas
# 2  boyingresign netizens galit kay doj chief remu...
# 3  backdoor entry grab motorcycle taxi pilot pina...
# 4                  doktor nangangamba mild stroke de
#
#                                    cleaned tokenized  period%    comma%  \
# 0      [lalaki, patay, pamamaril, tondo, ,, maynila]      0.0  0.125000
# 1  [50, pinoy, naipit, kaguluhan, sudan, ,, naili...      0.0  0.090909
# 2  [#, boyingresign, :, netizens, galit, kay, doj...      0.0  0.000000
# 3  [‘, backdoor, entry, ’, grab, motorcycle, taxi...      0.0  0.000000
# 4         [doktor, nangangamba, na-mild, stroke, de]      0.0  0.000000
#
#      colon%  semicolon%  question mark%  exclamation mark%     dash%  \
# 0  0.000000         0.0             0.0                0.0  0.000000
# 1  0.000000         0.0             0.0                0.0  0.000000
# 2  0.055556         0.0             0.0                0.0  0.055556
# 3  0.000000         0.0             0.0                0.0  0.000000
# 4  0.000000         0.0             0.0                0.0  0.125000
#
#    apostrophe%  open parenthesis%  close parenthesis%  capitalized%  \
# 0          0.0                0.0                 0.0      0.000000
# 1          0.0                0.0                 0.0      0.000000
# 2          0.0                0.0                 0.0      0.055556
# 3          0.0                0.0                 0.0      0.000000
# 4          0.0                0.0                 0.0      0.000000
#
#    slang words%  curse words%  with numericals%  \
# 0           0.0           0.0          0.000000
# 1           0.0           0.0          0.090909
# 2           0.0           0.0          0.000000
# 3           0.0           0.0          0.000000
# 4           0.0           0.0          0.000000
#
#                                              bigrams  \
# 0  [lalaki patay, patay pamamaril, pamamaril tond...
# 1  [50 pinoy, pinoy naipit, naipit kaguluhan, kag...
# 2  [boyingresign netizens, netizens galit, galit ...
# 3  [backdoor entry, entry grab, grab motorcycle, ...
# 4  [doktor nangangamba, nangangamba mild, mild st...
#
#                                             trigrams
# 0  [lalaki patay pamamaril, patay pamamaril tondo...
# 1  [50 pinoy naipit, pinoy naipit kaguluhan, naip...
# 2  [boyingresign netizens galit, netizens galit k...
# 3  [backdoor entry grab, entry grab motorcycle, g...
# 4  [doktor nangangamba mild, nangangamba mild str...

# %%
df = df.loc[:, (df != 0).any(axis=0)]
df.to_csv('Tagalog_Headlines_EngFeatures.csv', index=False)
df.to_pickle('Tagalog_Headlines_EngFeatures')

# %%
df = pd.read_pickle('Tagalog_Headlines_EngFeatures')

# %%
df[df['Rating'] == 'Real']['slang words%'].describe()
# Out:
# count    1734.000000
# mean        0.000041
# std         0.000766
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.018182
# Name: slang words%, dtype: float64

# %%
df[df['Rating'] == 'Fake']['slang words%'].describe()
# Out:
# count    1718.000000
# mean        0.000173
# std         0.001414
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.020202
# Name: slang words%, dtype: float64

# %%
def get_stats(df, col, rating):
    print(f'sum of all percentages of {col} in {rating} headlines {(df[df["Rating"] == rating][col].sum())}' )
    print(f'frequency of {col} in {rating} headlines {sum((df[df["Rating"] == rating][col] > 0).values)}' )
    print(f'{df[df["Rating"] == rating][col].describe()}')

# %%
df.columns
# Out:
# Index(['Statement', 'Rating', 'cleaned', 'cleaned tokenized', 'period%',
#        'comma%', 'colon%', 'semicolon%', 'question mark%', 'exclamation mark%',
#        'dash%', 'apostrophe%', 'close parenthesis%', 'capitalized%',
#        'slang words%', 'curse words%', 'with numericals%', 'bigrams',
#        'trigrams'],
#       dtype='object')

# %%
get_stats(df, 'slang words%', "Real")
get_stats(df, 'slang words%', "Fake")
# Out:
# sum of all percentages of slang words% in Real headlines 0.07052614052614052
# frequency of slang words% in Real headlines 5
# count    1734.000000
# mean        0.000041
# std         0.000766
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.018182
# Name: slang words%, dtype: float64
# sum of all percentages of slang words% in Fake headlines 0.2970577459273405
# frequency of slang words% in Fake headlines 27
# count    1718.000000
# mean        0.000173
# std         0.001414
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.020202
# Name: slang words%, dtype: float64

# %%
get_stats(df, 'period%', "Real")
get_stats(df, 'period%', "Fake")
# Out:
# sum of all percentages of period% in Real headlines 16.53247670674848
# frequency of period% in Real headlines 188
# count    1734.000000
# mean        0.009534
# std         0.030679
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.375000
# Name: period%, dtype: float64
# sum of all percentages of period% in Fake headlines 25.544654554510682
# frequency of period% in Fake headlines 405
# count    1718.000000
# mean        0.014869
# std         0.029908
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.250000
# Name: period%, dtype: float64

# %%
get_stats(df, 'question mark%', "Real")
get_stats(df, 'question mark%', "Fake")
# Out:
# sum of all percentages of question mark% in Real headlines 1.7059068983991583
# frequency of question mark% in Real headlines 20
# count    1734.000000
# mean        0.000984
# std         0.009904
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.200000
# Name: question mark%, dtype: float64
# sum of all percentages of question mark% in Fake headlines 5.787157175318999
# frequency of question mark% in Fake headlines 100
# count    1718.000000
# mean        0.003369
# std         0.014690
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.176471
# Name: question mark%, dtype: float64

# %%
get_stats(df, 'apostrophe%', "Real")
get_stats(df, 'apostrophe%', "Fake")
# Out:
# sum of all percentages of apostrophe% in Real headlines 11.9184598210527
# frequency of apostrophe% in Real headlines 89
# count    1734.000000
# mean        0.006873
# std         0.031495
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.222222
# Name: apostrophe%, dtype: float64
# sum of all percentages of apostrophe% in Fake headlines 14.488815436668446
# frequency of apostrophe% in Fake headlines 166
# count    1718.000000
# mean        0.008434
# std         0.028936
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.333333
# Name: apostrophe%, dtype: float64

# %%
get_stats(df, "with numericals%", "Real")
get_stats(df, "with numericals%", "Fake")
# Out:
# sum of all percentages of with numericals% in Real headlines 45.171082512603604
# frequency of with numericals% in Real headlines 472
# count    1734.000000
# mean        0.026050
# std         0.047271
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.055556
# max         0.333333
# Name: with numericals%, dtype: float64
# sum of all percentages of with numericals% in Fake headlines 18.8706115295653
# frequency of with numericals% in Fake headlines 285
# count    1718.000000
# mean        0.010984
# std         0.027047
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.181818
# Name: with numericals%, dtype: float64

# %%
get_stats(df, "capitalized%", "Real")
get_stats(df, "capitalized%", "Fake")
# Out:
# sum of all percentages of capitalized% in Real headlines 86.79153847794959
# frequency of capitalized% in Real headlines 841
# count    1734.000000
# mean        0.050053
# std         0.062648
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.090909
# max         0.400000
# Name: capitalized%, dtype: float64
# sum of all percentages of capitalized% in Fake headlines 59.29804567205229
# frequency of capitalized% in Fake headlines 355
# count    1718.000000
# mean        0.034516
# std         0.127512
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.967742
# Name: capitalized%, dtype: float64

# %%
get_stats(df, "curse words%", "Real")
get_stats(df, "curse words%", "Fake")
# Out:
# sum of all percentages of curse words% in Real headlines 0.0
# frequency of curse words% in Real headlines 0
# count    1734.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# Name: curse words%, dtype: float64
# sum of all percentages of curse words% in Fake headlines 0.0430971510605467
# frequency of curse words% in Fake headlines 4
# count    1718.000000
# mean        0.000025
# std         0.000522
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.012346
# Name: curse words%, dtype: float64

# %%
get_stats(df, "exclamation mark%", "Real")
get_stats(df, "exclamation mark%", "Fake")
# Out:
# sum of all percentages of exclamation mark% in Real headlines 1.6826802138873076
# frequency of exclamation mark% in Real headlines 20
# count    1734.000000
# mean        0.000970
# std         0.009697
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.166667
# Name: exclamation mark%, dtype: float64
# sum of all percentages of exclamation mark% in Fake headlines 23.514214979462608
# frequency of exclamation mark% in Fake headlines 334
# count    1718.000000
# mean        0.013687
# std         0.031846
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.300000
# Name: exclamation mark%, dtype: float64

# %%
df_real = df[df['Rating'] == 'Real']
df_fake = df[df['Rating'] == 'Fake']

# %%
real_news_words = []
fake_news_words = []
for l in df[df['Rating'] == 'Real']['cleaned'].values:
    l = [word for word in l.split() if word.isalpha()]
    for token in l:
        real_news_words.append(token)

for l in df[df['Rating'] == 'Fake']['cleaned'].values:
    l = [word for word in l.split() if word.isalpha()]
    for token in l:
        fake_news_words.append(token)

# %%
real_news_words_freq = pd.Series(real_news_words).value_counts()[:16]
real_news_words_freq = pd.DataFrame(real_news_words_freq, columns=['Frequency'])
real_news_words_freq
# Out:
#            Frequency
# marcos            76
# bansa             71
# kay               68
# matapos           66
# patay             60
# ilang             52
# covid             52
# pnp               51
# umano             49
# pilipinas         48
# teves             44
# rin               43
# ngayong           42
# city              42
# qc                41
# arestado          41

# %%
fake_news_words_freq = pd.Series(fake_news_words).value_counts()[:16]
fake_news_words_freq = pd.DataFrame(fake_news_words_freq, columns=['Frequency'])
fake_news_words_freq
# Out:
#           Frequency
# anak            200
# matapos         168
# lang            116
# the             107
# to               97
# buhay            86
# netizen          81
# netizens         78
# anyos            67
# dating           66
# ina              62
# of               61
# kay              60
# batang           57
# and              55
# araw             53

# %%
unique_to_real = pd.Series([word for word in real_news_words if word not in fake_news_words])
unique_to_real = unique_to_real.value_counts()[:16]
unique_to_real = pd.DataFrame(unique_to_real, columns=['Frequency'])
unique_to_real

# ngrams = pd.Series(l)
# ngrams_sorted = ngrams.value_counts()
# ngrams_sorted = ngrams_sorted[ngrams_sorted > threshold][:top].sort_values(ascending=True)
# Out:
#            Frequency
# qc                41
# degamo            33
# senador           31
# chief             29
# doh               27
# pagpatay          26
# posibleng         26
# sim               25
# kamara            24
# pagasa            24
# lpa               23
# mindoro           23
# lindol            23
# spill             21
# luzon             19
# ofws              18

# %%
unique_to_fake = pd.Series([word for word in fake_news_words if word not in real_news_words])
unique_to_fake = unique_to_fake.value_counts()[:16]
unique_to_fake = pd.DataFrame(unique_to_fake, columns=['Frequency'])
unique_to_fake
# Out:
#               Frequency
# lolo                 43
# customer             30
# estudyanteng         28
# nangyari             28
# sikat                26
# sobrang              22
# aktres               18
# amo                  17
# nya                  17
# nakapagtapos         17
# nagtapos             16
# perang               15
# diaz                 15
# hinangaan            15
# tindera              14
# people               14

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
def wordcloud_generator(data, file_name):

    stopwords = tl_stopwords
    text = ' '
    for x in data.Statement: 
        
        # typecaste each val to string 
        x =  re.sub("[^a-zA-Z0-9]+", " ", str(x))
    
        # split the value 
        values = x.split() 
        
        # Converts each token into lowercase 
        for i in range(len(values)): 
            values[i] = values[i].lower() 
            
        for words in values: 
            text = text + words + ' '
    
    
    wc = WordCloud(max_words= 100,
                        width = 744, 
                        height = 544,
                        background_color ='white',
                        stopwords=stopwords, 
                        contour_width=3, 
                        contour_color='steelblue',
                        min_font_size = 10).generate(text) 
    
    # plot the WordCloud image                        
    plt.figure(figsize = (14, 14)) 
    plt.imshow(wc) 
    plt.axis("off")
    plt.savefig(file_name)

wordcloud_generator(df, 'Visualizations/ALL_TAGALOG_headlines_wordcloud.png')

# %%
wordcloud_generator(df_real, 'Visualizations/REAL_TAGALOG_headlines_wordcloud.png')

# %%
wordcloud_generator(df_fake, 'Visualizations/FAKE_TAGALOG_headlines_wordcloud.png')

# %%
import matplotlib.pyplot as plt

# %%
def n_gram_graph(df_col, threshold = 5, top=0, size=(10,10), where='whole TAGALOG dataset'):
    l = []
    for arr in df_col.values:
        for list in arr:
            for ngram in list:
                l.append(ngram)
    
    ngrams = pd.Series(l)
    ngrams_sorted = ngrams.value_counts()
    ngrams_sorted = ngrams_sorted[ngrams_sorted > threshold][:top].sort_values(ascending=True)
    title = f'Most frequent {df_col.columns[0]} in {where}'
    ngrams_sorted.plot(kind='barh', title=title, figsize=size)
    plt.savefig(f'Visualizations\{title}')
    ngram_freq = pd.Series(ngrams_sorted.sort_values(ascending=False))
    ngram_freq = pd.DataFrame(ngram_freq, columns=['Frequency']).iloc[:40]
    display(ngram_freq)

# %%
n_gram_graph(df[['bigrams']], threshold=2, top=40)
# Out:
#                   Frequency
# covid 19                 51
# nga ba                   33
# social media             32
# delivery rider           23
# metro manila             22
# oil spill                21
# of the                   21
# cum laude                20
# watch from               19
# year old                 17
# negros oriental          17
# pangulong marcos         16
# bongbong marcos          15
# patay matapos            15
# araw araw                14
# kakapasok lang           14
# bong go                  14
# taong gulang             14
# puso netizens            13
# 2022 watch               13
# taxi driver              13
# semana santa             13
# pres marcos              13
# the philippines          13
# sim registration         12
# anyos lolo               12
# no 1                     12
# quezon city              12
# signal no                12
# humihingi tulong         12
# cover up                 11
# anyos lola               11
# degamo slay              11
# tricycle driver          11
# magna cum                11
# good samaritan           11
# gov degamo               11
# pagpatay kay             10
# holy week                10
# kay gov                  10

# %%
n_gram_graph(df[['trigrams']], threshold=2, top=40)
# Out:
#                           Frequency
# 2022 watch from                  12
# magna cum laude                  11
# signal no 1                      10
# kay gov degamo                    9
# oil spill mindoro                 9
# of the philippines                8
# viral social media                8
# official youtube channel          6
# pagpatay kay gov                  6
# apektado oil spill                6
# 2023 watch from                   6
# menor de edad                     6
# face to face                      6
# live in partner                   5
# 000 libong piso                   5

# %%
n_gram_graph(df_real[['bigrams']], threshold=2, top=40, where='TAGALOG real news')
# Out:
#                   Frequency
# covid 19                 49
# metro manila             22
# oil spill                21
# pangulong marcos         16
# negros oriental          16
# patay matapos            14
# bong go                  14
# semana santa             13
# bongbong marcos          13
# sim registration         12
# signal no                12
# gov degamo               11
# cover up                 11
# degamo slay              11
# no 1                     11

# %%
n_gram_graph(df_fake[['bigrams']], threshold=2, top=40, where='TAGALOG fake news')
# Out:
#                   Frequency
# social media             28
# nga ba                   27
# delivery rider           23
# watch from               19
# cum laude                19
# of the                   17
# year old                 16
# kakapasok lang           14
# 2022 watch               13
# puso netizens            13
# taong gulang             12
# the philippines          12
# anyos lolo               12
# araw araw                12
# humihingi tulong         11

# %%
n_gram_graph(df_real[['trigrams']], threshold=2, top=40, where='TAGALOG real news')
# Out:
#                         Frequency
# signal no 1                    10
# kay gov degamo                  9
# oil spill mindoro               9
# pagpatay kay gov                6
# apektado oil spill              6
# omicron subvariant xbb          5
# no 1 nakataas                   5
# doj chief remulla               5
# ngayong semana santa            5
# sim card registration           5
# menor de edad                   5
# subvariant xbb 1                5
# 19 positivity rate              4
# covid 19 vaccines               4
# war on drugs                    4

# %%
n_gram_graph(df_fake[['trigrams']], threshold=2, top=40, where='TAGALOG fake news')
# Out:
#                           Frequency
# 2022 watch from                  12
# magna cum laude                  10
# viral social media                8
# of the philippines                7
# 2023 watch from                   6
# official youtube channel          6
# 24 oras express                   5
# nagtapos magna cum                5
# 000 libong piso                   5
# abs cbn news                      4
# naaalala niyo ba                  4
# source senate of                  4
# vines breaking news               4
# netizen humihingi tulong          4
# source abs cbn                    4

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Rating'] = le.fit_transform(df.Rating.values)

# %%
import seaborn as sns
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize = (15,  15))
g = sns.heatmap(df[top_corr_features].corr(), vmin=-1, vmax=1, annot=True , cmap = 'RdYlGn')

# %%
import seaborn as sns
corrmat = df.corr()
top_corr_features = corrmat.index
sorted_feat = pd.Series(df[top_corr_features].corr()['Rating'].sort_values(ascending=False))
pd.DataFrame(sorted_feat)
# Out:
#                       Rating
# Rating              1.000000
# with numericals%    0.191810
# capitalized%        0.077230
# dash%               0.051670
# colon%              0.041780
# semicolon%          0.026883
# comma%             -0.006978
# apostrophe%        -0.025788
# close parenthesis% -0.030222
# curse words%       -0.034047
# slang words%       -0.058130
# period%            -0.087719
# question mark%     -0.094858
# exclamation mark%  -0.261305
