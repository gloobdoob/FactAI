# %%
import pandas as pd

# %%
df = pd.read_csv('CNN_Experiment_Results_ENGLISH.csv')

# %%
import numpy as np
df.accuracy = np.array(df.accuracy.values*100, dtype='int32')

# %%
df[df['accuracy']==78]
# Out:
#      Unnamed: 0       hl_f       ol_f   k_f  accuracy      loss
# 369         369  LeakyReLU  LeakyReLU  Adam        78  2.063118
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df
# Out:
#      Unnamed: 0     hl_f     ol_f      k_f  accuracy          loss
# 0             0  sigmoid  sigmoid      SGD        49           NaN
# 1             1  sigmoid  sigmoid      SGD        49  6.932043e-01
# 2             2  sigmoid  sigmoid      SGD        49  6.931891e-01
# 3             3  sigmoid  sigmoid      SGD        49  0.000000e+00
# 4             4  sigmoid  sigmoid  RMSprop        49           NaN
# ..          ...      ...      ...      ...       ...           ...
# 495         495    PReLU    PReLU  Adagrad        49           NaN
# 496         496    PReLU    PReLU   Adamax        49           NaN
# 497         497    PReLU    PReLU   Adamax        82  8.660145e-01
# 498         498    PReLU    PReLU   Adamax        81  7.813532e-01
# 499         499    PReLU    PReLU   Adamax        49  5.996865e-08
#
# [500 rows x 6 columns]

# %%
df.sort_values(by='accuracy', ascending=False).iloc[:15]
# Out:
#      Unnamed: 0       hl_f       ol_f      k_f  accuracy      loss
# 106         106       tanh    sigmoid  RMSprop  0.842748  1.810555
# 109         109       tanh    sigmoid     Adam  0.839695  0.871425
# 105         105       tanh    sigmoid  RMSprop  0.838931  1.850355
# 405         405      PReLU    sigmoid  RMSprop  0.837405  1.523167
# 406         406      PReLU    sigmoid  RMSprop  0.836641  1.446959
# 206         206       relu    sigmoid  RMSprop  0.835114  1.601950
# 9             9    sigmoid    sigmoid     Adam  0.835114  0.732419
# 98           98    sigmoid      PReLU   Adamax  0.834351  0.722185
# 357         357  LeakyReLU       relu   Adamax  0.834351  0.799119
# 78           78    sigmoid  LeakyReLU   Adamax  0.833588  0.749584
# 205         205       relu    sigmoid  RMSprop  0.833588  1.547730
# 305         305  LeakyReLU    sigmoid  RMSprop  0.832061  1.662906
# 410         410      PReLU    sigmoid     Adam  0.832061  1.069572
# ...

# %%
df2 = pd.read_csv('RNN_Experimentation_ENGLISH.csv')

# %%
df2.sort_values(by='accuracy', ascending=False).iloc[:15]
# Out:
#      Unnamed: 0       hl_f       ol_f      k_f  accuracy      loss
# 56           56       relu       tanh  RMSprop  0.820611  0.509649
# 51           51       relu    sigmoid  RMSprop  0.820611  0.400756
# 102         102      PReLU    sigmoid     Adam  0.820611  0.368475
# 26           26       tanh    sigmoid  RMSprop  0.815267  0.386266
# 76           76  LeakyReLU    sigmoid  RMSprop  0.815267  0.396769
# 52           52       relu    sigmoid     Adam  0.812977  0.379632
# 91           91  LeakyReLU  LeakyReLU  RMSprop  0.811450  0.528222
# 2             2    sigmoid    sigmoid     Adam  0.810687  0.400457
# 29           29       tanh    sigmoid   Adamax  0.808397  0.392985
# 96           96  LeakyReLU      PReLU  RMSprop  0.807634  0.426603
# 121         121      PReLU      PReLU  RMSprop  0.806107  0.506312
# 106         106      PReLU       tanh  RMSprop  0.804580  0.447515
# 1             1    sigmoid    sigmoid  RMSprop  0.803817  0.409422
# ...
